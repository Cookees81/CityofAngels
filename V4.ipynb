# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
from scipy.stats import linregress

# Study data files
LAcrime_path = "Resources/Crime_Data_from_2020_to_Present.csv"

# Read the Los Angeles Crime data 
LACrime = pd.read_csv(LAcrime_path)

# Display the data table for preview
LACrime
# Out:
#             DR_NO               Date Rptd                DATE OCC  TIME OCC  \
# 0        10304468  01/08/2020 12:00:00 AM  01/08/2020 12:00:00 AM      2230
# 1       190101086  01/02/2020 12:00:00 AM  01/01/2020 12:00:00 AM       330
# 2       200110444  04/14/2020 12:00:00 AM  02/13/2020 12:00:00 AM      1200
# 3       191501505  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM      1730
# 4       191921269  01/01/2020 12:00:00 AM  01/01/2020 12:00:00 AM       415
# ...           ...                     ...                     ...       ...
# 811658  231604807  01/27/2023 12:00:00 AM  01/26/2023 12:00:00 AM      1800
# 811659  231606525  03/22/2023 12:00:00 AM  03/22/2023 12:00:00 AM      1000
# 811660  231210064  04/12/2023 12:00:00 AM  04/12/2023 12:00:00 AM      1630
# 811661  230115220  07/02/2023 12:00:00 AM  07/01/2023 12:00:00 AM         1
# 811662  230906458  03/05/2023 12:00:00 AM  03/05/2023 12:00:00 AM       900
#
#         AREA    AREA NAME  Rpt Dist No  Part 1-2  Crm Cd  \
# 0          3    Southwest          377         2     624
# 1          1      Central          163         2     624
# 2          1      Central          155         2     845
# 3         15  N Hollywood         1543         2     745
# 4         19      Mission         1998         2     740
# ...      ...          ...          ...       ...     ...
# 811658    16     Foothill         1663         2     740
# 811659    16     Foothill         1602         1     230
# 811660    12  77th Street         1239         1     230
# 811661     1      Central          154         1     352
# 811662     9     Van Nuys          914         2     745
#
#                                               Crm Cd Desc  ... Status  \
# 0                                BATTERY - SIMPLE ASSAULT  ...     AO
# 1                                BATTERY - SIMPLE ASSAULT  ...     IC
# 2               SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3                VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# 4       VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# ...                                                   ...  ...    ...
# 811658  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...  ...     IC
# 811659     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 811660     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT  ...     IC
# 811661                                         PICKPOCKET  ...     IC
# 811662           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
#
#          Status Desc Crm Cd 1 Crm Cd 2  Crm Cd 3 Crm Cd 4  \
# 0        Adult Other    624.0      NaN       NaN      NaN
# 1        Invest Cont    624.0      NaN       NaN      NaN
# 2       Adult Arrest    845.0      NaN       NaN      NaN
# 3        Invest Cont    745.0    998.0       NaN      NaN
# 4        Invest Cont    740.0      NaN       NaN      NaN
# ...              ...      ...      ...       ...      ...
# 811658   Invest Cont    740.0      NaN       NaN      NaN
# 811659   Invest Cont    230.0      NaN       NaN      NaN
# 811660   Invest Cont    230.0      NaN       NaN      NaN
# 811661   Invest Cont    352.0      NaN       NaN      NaN
# 811662   Invest Cont    745.0      NaN       NaN      NaN
#
#                                         LOCATION Cross Street      LAT  \
# 0        1100 W  39TH                         PL          NaN  34.0141
# 1         700 S  HILL                         ST          NaN  34.0459
# 2         200 E  6TH                          ST          NaN  34.0448
# 3        5400    CORTEEN                      PL          NaN  34.1685
# 4       14400    TITUS                        ST          NaN  34.2198
# ...                                          ...          ...      ...
# 811658  12500    BRANFORD                     ST          NaN  34.2466
# 811659  12800    FILMORE                      ST          NaN  34.2790
# 811660   6100 S  VERMONT                      AV          NaN  33.9841
# 811661    500 S  MAIN                         ST          NaN  34.0467
# 811662  14500    HARTLAND                     ST          NaN  34.1951
#
#              LON
# 0      -118.2978
# 1      -118.2545
# 2      -118.2474
# 3      -118.4019
# 4      -118.4468
# ...          ...
# 811658 -118.4054
# 811659 -118.4116
# 811660 -118.2915
# 811661 -118.2485
# 811662 -118.4487
#
# [811663 rows x 28 columns]

# %%
# Display the data table info for preview
LACrime.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 811663 entries, 0 to 811662
# Data columns (total 28 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           811663 non-null  int64
#  1   Date Rptd       811663 non-null  object
#  2   DATE OCC        811663 non-null  object
#  3   TIME OCC        811663 non-null  int64
#  4   AREA            811663 non-null  int64
#  5   AREA NAME       811663 non-null  object
#  6   Rpt Dist No     811663 non-null  int64
#  7   Part 1-2        811663 non-null  int64
#  8   Crm Cd          811663 non-null  int64
#  9   Crm Cd Desc     811663 non-null  object
#  10  Mocodes         699639 non-null  object
#  11  Vict Age        811663 non-null  int64
#  12  Vict Sex        705139 non-null  object
#  13  Vict Descent    705131 non-null  object
#  14  Premis Cd       811654 non-null  float64
#  15  Premis Desc     811184 non-null  object
#  16  Weapon Used Cd  282783 non-null  float64
#  17  Weapon Desc     282783 non-null  object
#  18  Status          811663 non-null  object
#  19  Status Desc     811663 non-null  object
#  20  Crm Cd 1        811653 non-null  float64
#  21  Crm Cd 2        59815 non-null   float64
#  22  Crm Cd 3        2000 non-null    float64
#  23  Crm Cd 4        60 non-null      float64
#  24  LOCATION        811663 non-null  object
#  25  Cross Street    129872 non-null  object
#  26  LAT             811663 non-null  float64
#  27  LON             811663 non-null  float64
# dtypes: float64(8), int64(7), object(13)
# memory usage: 173.4+ MB

# %%
# Checking the number of LA Area covered.
area = LACrime["AREA NAME"].nunique()
area
# Out:
# 21

# %%
# Group the data by 'Area Name'
grouped = LACrime.groupby("AREA NAME")

# Iterate through the groups and display each weapon description
for area, group in grouped:
    print(f"Area covered: {area}")
# Out:
# Area covered: 77th Street
# Area covered: Central
# Area covered: Devonshire
# Area covered: Foothill
# Area covered: Harbor
# Area covered: Hollenbeck
# Area covered: Hollywood
# Area covered: Mission
# Area covered: N Hollywood
# Area covered: Newton
# Area covered: Northeast
# Area covered: Olympic
# Area covered: Pacific
# Area covered: Rampart
# Area covered: Southeast
# Area covered: Southwest
# Area covered: Topanga
# Area covered: Van Nuys
# Area covered: West LA
# Area covered: West Valley
# Area covered: Wilshire

# %%
# Checking the number of Crime Descriptions.
CrimeDescription = LACrime["Crm Cd Desc"].nunique()
CrimeDescription
# Out:
# 138

# %%
# Group the data by 'Crime Descriptions'
grouped = LACrime.groupby("Crm Cd Desc")

# Iterate through the groups and display each Crime description
for crimeDesc, group in grouped:
    print(f"Crime Description: {crimeDesc}")
# Out:
# Crime Description: ARSON
# Crime Description: ASSAULT WITH DEADLY WEAPON ON POLICE OFFICER
# Crime Description: ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# Crime Description: ATTEMPTED ROBBERY
# Crime Description: BATTERY - SIMPLE ASSAULT
# Crime Description: BATTERY ON A FIREFIGHTER
# Crime Description: BATTERY POLICE (SIMPLE)
# Crime Description: BATTERY WITH SEXUAL CONTACT
# Crime Description: BEASTIALITY, CRIME AGAINST NATURE SEXUAL ASSLT WITH ANIM
# Crime Description: BIGAMY
# Crime Description: BIKE - ATTEMPTED STOLEN
# Crime Description: BIKE - STOLEN
# Crime Description: BLOCKING DOOR INDUCTION CENTER
# Crime Description: BOAT - STOLEN
# Crime Description: BOMB SCARE
# Crime Description: BRANDISH WEAPON
# Crime Description: BRIBERY
# Crime Description: BUNCO, ATTEMPT
# Crime Description: BUNCO, GRAND THEFT
# Crime Description: BUNCO, PETTY THEFT
# Crime Description: BURGLARY
# Crime Description: BURGLARY FROM VEHICLE
# Crime Description: BURGLARY FROM VEHICLE, ATTEMPTED
# Crime Description: BURGLARY, ATTEMPTED
# Crime Description: CHILD ABANDONMENT
# Crime Description: CHILD ABUSE (PHYSICAL) - AGGRAVATED ASSAULT
# Crime Description: CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT
# Crime Description: CHILD ANNOYING (17YRS & UNDER)
# Crime Description: CHILD NEGLECT (SEE 300 W.I.C.)
# Crime Description: CHILD PORNOGRAPHY
# Crime Description: CHILD STEALING
# Crime Description: CONSPIRACY
# Crime Description: CONTEMPT OF COURT
# Crime Description: CONTRIBUTING
# Crime Description: COUNTERFEIT
# Crime Description: CREDIT CARDS, FRAUD USE ($950 & UNDER
# Crime Description: CREDIT CARDS, FRAUD USE ($950.01 & OVER)
# Crime Description: CRIMINAL HOMICIDE
# Crime Description: CRIMINAL THREATS - NO WEAPON DISPLAYED
# Crime Description: CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 YRS OLDER)
# Crime Description: CRUELTY TO ANIMALS
# Crime Description: DEFRAUDING INNKEEPER/THEFT OF SERVICES, $950 & UNDER
# Crime Description: DEFRAUDING INNKEEPER/THEFT OF SERVICES, OVER $950.01
# Crime Description: DISCHARGE FIREARMS/SHOTS FIRED
# Crime Description: DISHONEST EMPLOYEE - GRAND THEFT
# Crime Description: DISHONEST EMPLOYEE - PETTY THEFT
# Crime Description: DISHONEST EMPLOYEE ATTEMPTED THEFT
# Crime Description: DISRUPT SCHOOL
# Crime Description: DISTURBING THE PEACE
# Crime Description: DOCUMENT FORGERY / STOLEN FELONY
# Crime Description: DOCUMENT WORTHLESS ($200 & UNDER)
# Crime Description: DOCUMENT WORTHLESS ($200.01 & OVER)
# Crime Description: DRIVING WITHOUT OWNER CONSENT (DWOC)
# Crime Description: DRUGS, TO A MINOR
# Crime Description: DRUNK ROLL
# Crime Description: EMBEZZLEMENT, GRAND THEFT ($950.01 & OVER)
# Crime Description: EMBEZZLEMENT, PETTY THEFT ($950 & UNDER)
# Crime Description: EXTORTION
# Crime Description: FAILURE TO DISPERSE
# Crime Description: FAILURE TO YIELD
# Crime Description: FALSE IMPRISONMENT
# Crime Description: FALSE POLICE REPORT
# Crime Description: FIREARMS EMERGENCY PROTECTIVE ORDER (FIREARMS EPO)
# Crime Description: FIREARMS RESTRAINING ORDER (FIREARMS RO)
# Crime Description: GRAND THEFT / AUTO REPAIR
# Crime Description: GRAND THEFT / INSURANCE FRAUD
# Crime Description: HUMAN TRAFFICKING - COMMERCIAL SEX ACTS
# Crime Description: HUMAN TRAFFICKING - INVOLUNTARY SERVITUDE
# Crime Description: ILLEGAL DUMPING
# Crime Description: INCEST (SEXUAL ACTS BETWEEN BLOOD RELATIVES)
# Crime Description: INCITING A RIOT
# Crime Description: INDECENT EXPOSURE
# Crime Description: INTIMATE PARTNER - AGGRAVATED ASSAULT
# Crime Description: INTIMATE PARTNER - SIMPLE ASSAULT
# Crime Description: KIDNAPPING
# Crime Description: KIDNAPPING - GRAND ATTEMPT
# Crime Description: LETTERS, LEWD  -  TELEPHONE CALLS, LEWD
# Crime Description: LEWD CONDUCT
# Crime Description: LEWD/LASCIVIOUS ACTS WITH CHILD
# Crime Description: LYNCHING
# Crime Description: LYNCHING - ATTEMPTED
# Crime Description: MANSLAUGHTER, NEGLIGENT
# Crime Description: ORAL COPULATION
# Crime Description: OTHER ASSAULT
# Crime Description: OTHER MISCELLANEOUS CRIME
# Crime Description: PANDERING
# Crime Description: PEEPING TOM
# Crime Description: PETTY THEFT - AUTO REPAIR
# Crime Description: PICKPOCKET
# Crime Description: PICKPOCKET, ATTEMPT
# Crime Description: PIMPING
# Crime Description: PROWLER
# Crime Description: PURSE SNATCHING
# Crime Description: PURSE SNATCHING - ATTEMPT
# Crime Description: RAPE, ATTEMPTED
# Crime Description: RAPE, FORCIBLE
# Crime Description: RECKLESS DRIVING
# Crime Description: REPLICA FIREARMS(SALE,DISPLAY,MANUFACTURE OR DISTRIBUTE)
# Crime Description: RESISTING ARREST
# Crime Description: ROBBERY
# Crime Description: SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# Crime Description: SEX,UNLAWFUL(INC MUTUAL CONSENT, PENETRATION W/ FRGN OBJ
# Crime Description: SEXUAL PENETRATION W/FOREIGN OBJECT
# Crime Description: SHOPLIFTING - ATTEMPT
# Crime Description: SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# Crime Description: SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# Crime Description: SHOTS FIRED AT INHABITED DWELLING
# Crime Description: SHOTS FIRED AT MOVING VEHICLE, TRAIN OR AIRCRAFT
# Crime Description: SODOMY/SEXUAL CONTACT B/W PENIS OF ONE PERS TO ANUS OTH
# Crime Description: STALKING
# Crime Description: TELEPHONE PROPERTY - DAMAGE
# Crime Description: THEFT FROM MOTOR VEHICLE - ATTEMPT
# Crime Description: THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND OVER)
# Crime Description: THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)
# Crime Description: THEFT FROM PERSON - ATTEMPT
# Crime Description: THEFT OF IDENTITY
# Crime Description: THEFT PLAIN - ATTEMPT
# Crime Description: THEFT PLAIN - PETTY ($950 & UNDER)
# Crime Description: THEFT, COIN MACHINE - ATTEMPT
# Crime Description: THEFT, COIN MACHINE - GRAND ($950.01 & OVER)
# Crime Description: THEFT, COIN MACHINE - PETTY ($950 & UNDER)
# Crime Description: THEFT, PERSON
# Crime Description: THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LIVESTK,PROD
# Crime Description: THREATENING PHONE CALLS/LETTERS
# Crime Description: THROWING OBJECT AT MOVING VEHICLE
# Crime Description: TILL TAP - GRAND THEFT ($950.01 & OVER)
# Crime Description: TILL TAP - PETTY ($950 & UNDER)
# Crime Description: TRESPASSING
# Crime Description: UNAUTHORIZED COMPUTER ACCESS
# Crime Description: VANDALISM - FELONY ($400 & OVER, ALL CHURCH VANDALISMS)
# Crime Description: VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# Crime Description: VEHICLE - ATTEMPT STOLEN
# Crime Description: VEHICLE - STOLEN
# Crime Description: VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, BIKES, ETC)
# Crime Description: VIOLATION OF COURT ORDER
# Crime Description: VIOLATION OF RESTRAINING ORDER
# Crime Description: VIOLATION OF TEMPORARY RESTRAINING ORDER
# Crime Description: WEAPONS POSSESSION/BOMBING

# %%
# Checking the number of weapon types.
weapon_types = LACrime["Weapon Desc"].nunique()
weapon_types
# Out:
# 79

# %%
# Group the data by 'Weapon used Descriptions'
grouped = LACrime.groupby("Weapon Desc")

# Iterate through the groups and display each weapon description
for weapon, group in grouped:
    print(f"Weapon Description: {weapon}")
# Out:
# Weapon Description: AIR PISTOL/REVOLVER/RIFLE/BB GUN
# Weapon Description: ANTIQUE FIREARM
# Weapon Description: ASSAULT WEAPON/UZI/AK47/ETC
# Weapon Description: AUTOMATIC WEAPON/SUB-MACHINE GUN
# Weapon Description: AXE
# Weapon Description: BELT FLAILING INSTRUMENT/CHAIN
# Weapon Description: BLACKJACK
# Weapon Description: BLUNT INSTRUMENT
# Weapon Description: BOARD
# Weapon Description: BOMB THREAT
# Weapon Description: BOTTLE
# Weapon Description: BOW AND ARROW
# Weapon Description: BOWIE KNIFE
# Weapon Description: BRASS KNUCKLES
# Weapon Description: CAUSTIC CHEMICAL/POISON
# Weapon Description: CLEAVER
# Weapon Description: CLUB/BAT
# Weapon Description: CONCRETE BLOCK/BRICK
# Weapon Description: DEMAND NOTE
# Weapon Description: DIRK/DAGGER
# Weapon Description: DOG/ANIMAL (SIC ANIMAL ON)
# Weapon Description: EXPLOXIVE DEVICE
# Weapon Description: FIRE
# Weapon Description: FIXED OBJECT
# Weapon Description: FOLDING KNIFE
# Weapon Description: GLASS
# Weapon Description: HAMMER
# Weapon Description: HAND GUN
# Weapon Description: HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE
# Weapon Description: HECKLER & KOCH 93 SEMIAUTOMATIC ASSAULT RIFLE
# Weapon Description: ICE PICK
# Weapon Description: KITCHEN KNIFE
# Weapon Description: KNIFE WITH BLADE 6INCHES OR LESS
# Weapon Description: KNIFE WITH BLADE OVER 6 INCHES IN LENGTH
# Weapon Description: LIQUOR/DRUGS
# Weapon Description: M-14 SEMIAUTOMATIC ASSAULT RIFLE
# Weapon Description: M1-1 SEMIAUTOMATIC ASSAULT RIFLE
# Weapon Description: MAC-10 SEMIAUTOMATIC ASSAULT WEAPON
# Weapon Description: MAC-11 SEMIAUTOMATIC ASSAULT WEAPON
# Weapon Description: MACE/PEPPER SPRAY
# Weapon Description: MACHETE
# Weapon Description: MARTIAL ARTS WEAPONS
# Weapon Description: OTHER CUTTING INSTRUMENT
# Weapon Description: OTHER FIREARM
# Weapon Description: OTHER KNIFE
# Weapon Description: PHYSICAL PRESENCE
# Weapon Description: PIPE/METAL PIPE
# Weapon Description: RAZOR
# Weapon Description: RAZOR BLADE
# Weapon Description: RELIC FIREARM
# Weapon Description: REVOLVER
# Weapon Description: RIFLE
# Weapon Description: ROCK/THROWN OBJECT
# Weapon Description: ROPE/LIGATURE
# Weapon Description: SAWED OFF RIFLE/SHOTGUN
# Weapon Description: SCALDING LIQUID
# Weapon Description: SCISSORS
# Weapon Description: SCREWDRIVER
# Weapon Description: SEMI-AUTOMATIC PISTOL
# Weapon Description: SEMI-AUTOMATIC RIFLE
# Weapon Description: SHOTGUN
# Weapon Description: SIMULATED GUN
# Weapon Description: STARTER PISTOL/REVOLVER
# Weapon Description: STICK
# Weapon Description: STRAIGHT RAZOR
# Weapon Description: STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)
# Weapon Description: STUN GUN
# Weapon Description: SWITCH BLADE
# Weapon Description: SWORD
# Weapon Description: SYRINGE
# Weapon Description: TIRE IRON
# Weapon Description: TOY GUN
# Weapon Description: UNK TYPE SEMIAUTOMATIC ASSAULT RIFLE
# Weapon Description: UNKNOWN FIREARM
# Weapon Description: UNKNOWN TYPE CUTTING INSTRUMENT
# Weapon Description: UNKNOWN WEAPON/OTHER WEAPON
# Weapon Description: UZI SEMIAUTOMATIC ASSAULT RIFLE
# Weapon Description: VEHICLE
# Weapon Description: VERBAL THREAT

# %%
# Checking the number of gender in the data set.
gender = LACrime["Vict Sex"].nunique()
gender
# Out:
# 5

# %%
# Group the data by 'Gender Descriptions'
grouped = LACrime.groupby("Vict Sex")

# Iterate through the groups and display each gender description
for sex, group in grouped:
    print(f"Gender Description: {sex}")
# Out:
# Gender Description: -
# Gender Description: F
# Gender Description: H
# Gender Description: M
# Gender Description: X

# %%
# Checking the number of race descriptions.
race = LACrime["Vict Descent"].nunique()
race
# Out:
# 20

# %%
# Group the data by 'Race Group Descriptions'
grouped = LACrime.groupby("Vict Descent")

# Iterate through the groups and display different race group description
for race, group in grouped:
    print(f"Crime Description: {race}")
# Out:
# Crime Description: -
# Crime Description: A
# Crime Description: B
# Crime Description: C
# Crime Description: D
# Crime Description: F
# Crime Description: G
# Crime Description: H
# Crime Description: I
# Crime Description: J
# Crime Description: K
# Crime Description: L
# Crime Description: O
# Crime Description: P
# Crime Description: S
# Crime Description: U
# Crime Description: V
# Crime Description: W
# Crime Description: X
# Crime Description: Z

# %%
# Checking the number of Premis descriptions.
premis = LACrime["Premis Desc"].nunique()
premis
# Out:
# 306

# %%
# Group the data by 'Premis descriptions'
grouped = LACrime.groupby("Premis Desc")

# Iterate through the groups and display different Premis description
for premis, group in grouped:
    print(f"premis Description: {premis}")
# Out:
# premis Description: 7TH AND METRO CENTER (NOT LINE SPECIFIC)
# premis Description: ABANDONED BUILDING ABANDONED HOUSE
# premis Description: ABATEMENT LOCATION
# premis Description: ABORTION CLINIC/ABORTION FACILITY*
# premis Description: AIRCRAFT
# premis Description: ALLEY
# premis Description: AMTRAK TRAIN
# premis Description: AMUSEMENT PARK*
# premis Description: APARTMENT/CONDO COMMON LAUNDRY ROOM
# premis Description: ARCADE,GAME ROOM/VIDEO GAMES (EXAMPLE CHUCKIE CHEESE)*
# premis Description: AUTO DEALERSHIP (CHEVY, FORD, BMW, MERCEDES, ETC.)
# premis Description: AUTO REPAIR SHOP
# premis Description: AUTO SALES LOT
# premis Description: AUTO SUPPLY STORE*
# premis Description: AUTOMATED TELLER MACHINE (ATM)
# premis Description: BALCONY*
# premis Description: BANK
# premis Description: BANK DROP BOX/MONEY DROP-OUTSIDE OF BANK*
# premis Description: BANKING INSIDE MARKET-STORE *
# premis Description: BAR/COCKTAIL/NIGHTCLUB
# premis Description: BAR/SPORTS BAR (OPEN DAY & NIGHT)
# premis Description: BASKETBALL COURTS
# premis Description: BEACH
# premis Description: BEAUTY SUPPLY STORE
# premis Description: BEAUTY/BARBER SHOP
# premis Description: BOOK STORE
# premis Description: BOWLING ALLEY*
# premis Description: BUS DEPOT/TERMINAL, OTHER THAN MTA
# premis Description: BUS STOP
# premis Description: BUS STOP/LAYOVER (ALSO QUERY 124)
# premis Description: BUS, SCHOOL, CHURCH
# premis Description: BUS-CHARTER/PRIVATE
# premis Description: CAR WASH
# premis Description: CATERING/ICE CREAM TRUCK
# premis Description: CELL PHONE STORE
# premis Description: CEMETARY*
# premis Description: CHECK CASHING*
# premis Description: CHEMICAL STORAGE/MANUFACTURING PLANT
# premis Description: CHURCH/CHAPEL (CHANGED 03-03 FROM CHURCH/TEMPLE)
# premis Description: CLEANER/LAUNDROMAT
# premis Description: CLOTHING STORE
# premis Description: COFFEE SHOP (STARBUCKS, COFFEE BEAN, PEET'S, ETC.)
# premis Description: COLISEUM
# premis Description: COLLEGE/JUNIOR COLLEGE/UNIVERSITY
# premis Description: COMPUTER SERVICES/REPAIRS/SALES
# premis Description: CONDOMINIUM/TOWNHOUSE
# premis Description: CONSTRUCTION SITE
# premis Description: CONVENTION CENTER
# premis Description: CREDIT UNION
# premis Description: CULTURAL SIGNIFICANCE/MONUMENT
# premis Description: CYBERSPACE
# premis Description: DAM/RESERVOIR
# premis Description: DAY CARE/ADULTS*
# premis Description: DAY CARE/CHILDREN*
# premis Description: DELIVERY SERVICE (FED EX, UPS, COURIERS,COURIER SERVICE)*
# premis Description: DEPARTMENT STORE
# premis Description: DEPT OF DEFENSE FACILITY
# premis Description: DETENTION/JAIL FACILITY
# premis Description: DISCOUNT STORE (99 CENT,DOLLAR,ETC.
# premis Description: DIY CENTER (LOWE'S,HOME DEPOT,OSH,CONTRACTORS WAREHOUSE)
# premis Description: DODGER STADIUM
# premis Description: DRIVE THRU BANKING (WINDOW)*
# premis Description: DRIVE THRU*
# premis Description: DRIVEWAY
# premis Description: DRUG STORE
# premis Description: ELECTRONICS STORE (IE:RADIO SHACK, ETC.)
# premis Description: ELEMENTARY SCHOOL
# premis Description: ELEVATOR
# premis Description: ENERGY PLANT/FACILITY
# premis Description: ENTERTAINMENT/COMEDY CLUB (OTHER)
# premis Description: EQUIPMENT RENTAL
# premis Description: ESCALATOR*
# premis Description: FACTORY
# premis Description: FINANCE COMPANY
# premis Description: FIRE STATION
# premis Description: FOSTER HOME BOYS OR GIRLS*
# premis Description: FRAT HOUSE/SORORITY/DORMITORY
# premis Description: FREEWAY
# premis Description: FURNITURE STORE
# premis Description: GARAGE/CARPORT
# premis Description: GARMENT MANUFACTURER
# premis Description: GAS STATION
# premis Description: GOLF COURSE*
# premis Description: GOVERNMENT FACILITY (FEDERAL,STATE, COUNTY & CITY)
# premis Description: GREYHOUND OR INTERSTATE BUS
# premis Description: GROUP HOME
# premis Description: GUN/SPORTING GOODS
# premis Description: HANDBALL COURTS
# premis Description: HARBOR FRWY STATION (NOT LINE SPECIFIC)
# premis Description: HARDWARE/BUILDING SUPPLY
# premis Description: HEALTH SPA/GYM
# premis Description: HIGH SCHOOL
# premis Description: HIGH-RISE BUILDING
# premis Description: HOCKEY RINK/ICE HOCKEY
# premis Description: HORSE RACING/SANTA ANITA PARK*
# premis Description: HOSPICE
# premis Description: HOSPITAL
# premis Description: HOTEL
# premis Description: JEWELRY STORE
# premis Description: JUNIOR HIGH SCHOOL
# premis Description: LA UNION STATION (NOT LINE SPECIFIC)
# premis Description: LAUNDROMAT
# premis Description: LIBRARY
# premis Description: LIQUOR STORE
# premis Description: MAIL BOX
# premis Description: MANUFACTURING COMPANY
# premis Description: MARKET
# premis Description: MASS GATHERING LOCATION
# premis Description: MASSAGE PARLOR
# premis Description: MEDICAL MARIJUANA FACILITIES/BUSINESSES
# premis Description: MEDICAL/DENTAL OFFICES
# premis Description: MEMBERSHIP STORE (COSTCO,SAMS CLUB)*
# premis Description: METHADONE CLINIC
# premis Description: METROLINK TRAIN
# premis Description: MINI-MART
# premis Description: MISSIONS/SHELTERS
# premis Description: MOBILE HOME/TRAILERS/CONSTRUCTION TRAILERS/RV'S/MOTORHOME
# premis Description: MORTUARY
# premis Description: MOSQUE*
# premis Description: MOTEL
# premis Description: MTA - BLUE LINE - 103RD/WATTS TOWERS
# premis Description: MTA - BLUE LINE - 7TH AND METRO CENTER
# premis Description: MTA - BLUE LINE - GRAND/LATTC
# premis Description: MTA - BLUE LINE - PICO
# premis Description: MTA - BLUE LINE - SAN PEDRO
# premis Description: MTA - BLUE LINE - VERNON
# premis Description: MTA - BLUE LINE - WASHINGTON
# premis Description: MTA - EXPO LINE - 7TH AND METRO CENTER
# premis Description: MTA - EXPO LINE - EXPO PARK/USC
# premis Description: MTA - EXPO LINE - EXPO/BUNDY
# premis Description: MTA - EXPO LINE - EXPO/CRENSHAW
# premis Description: MTA - EXPO LINE - EXPO/LA BREA
# premis Description: MTA - EXPO LINE - EXPO/SEPULVEDA
# premis Description: MTA - EXPO LINE - EXPO/VERMONT
# premis Description: MTA - EXPO LINE - EXPO/WESTERN
# premis Description: MTA - EXPO LINE - FARMDALE
# premis Description: MTA - EXPO LINE - JEFFERSON/USC
# premis Description: MTA - EXPO LINE - LA CIENEGA/JEFFERSON
# premis Description: MTA - EXPO LINE - LATTC/ORTHO INSTITUTE
# premis Description: MTA - EXPO LINE - PALMS
# premis Description: MTA - EXPO LINE - PICO
# premis Description: MTA - EXPO LINE - WESTWOOD/RANCHO PARK
# premis Description: MTA - GOLD LINE - CHINATOWN
# premis Description: MTA - GOLD LINE - HERITAGE SQ
# premis Description: MTA - GOLD LINE - HIGHLAND PARK
# premis Description: MTA - GOLD LINE - INDIANA
# premis Description: MTA - GOLD LINE - LINCOLN/CYPRESS
# premis Description: MTA - GOLD LINE - LITTLE TOKYO/ARTS DISTRICT
# premis Description: MTA - GOLD LINE - MARIACHI PLAZA
# premis Description: MTA - GOLD LINE - PICO/ALISO
# premis Description: MTA - GOLD LINE - SOTO
# premis Description: MTA - GOLD LINE - SOUTHWEST MUSEUM
# premis Description: MTA - GOLD LINE - UNION STATION
# premis Description: MTA - GREEN LINE - AVALON
# premis Description: MTA - GREEN LINE - AVIATION/LAX
# premis Description: MTA - GREEN LINE - HARBOR FWY
# premis Description: MTA - ORANGE LINE - BALBOA
# premis Description: MTA - ORANGE LINE - CANOGA
# premis Description: MTA - ORANGE LINE - CHATSWORTH
# premis Description: MTA - ORANGE LINE - DE SOTO
# premis Description: MTA - ORANGE LINE - LAUREL CANYON
# premis Description: MTA - ORANGE LINE - NORDHOFF
# premis Description: MTA - ORANGE LINE - NORTH HOLLYWOOD
# premis Description: MTA - ORANGE LINE - PIERCE COLLEGE
# premis Description: MTA - ORANGE LINE - RESEDA
# premis Description: MTA - ORANGE LINE - ROSCOE
# premis Description: MTA - ORANGE LINE - SEPULVEDA
# premis Description: MTA - ORANGE LINE - SHERMAN WAY
# premis Description: MTA - ORANGE LINE - TAMPA
# premis Description: MTA - ORANGE LINE - VALLEY COLLEGE
# premis Description: MTA - ORANGE LINE - VAN NUYS
# premis Description: MTA - ORANGE LINE - WOODLEY
# premis Description: MTA - ORANGE LINE - WOODMAN
# premis Description: MTA - PURPLE LINE - 7TH AND METRO CENTER
# premis Description: MTA - PURPLE LINE - CIVIC CENTER/GRAND PARK
# premis Description: MTA - PURPLE LINE - PERSHING SQUARE
# premis Description: MTA - PURPLE LINE - UNION STATION
# premis Description: MTA - PURPLE LINE - WESTLAKE/MACARTHUR PARK
# premis Description: MTA - PURPLE LINE - WILSHIRE/NORMANDIE
# premis Description: MTA - PURPLE LINE - WILSHIRE/VERMONT
# premis Description: MTA - PURPLE LINE - WILSHIRE/WESTERN
# premis Description: MTA - RED LINE - 7TH AND METRO CENTER
# premis Description: MTA - RED LINE - CIVIC CENTER/GRAND PARK
# premis Description: MTA - RED LINE - HOLLYWOOD/HIGHLAND
# premis Description: MTA - RED LINE - HOLLYWOOD/VINE
# premis Description: MTA - RED LINE - HOLLYWOOD/WESTERN
# premis Description: MTA - RED LINE - NORTH HOLLYWOOD
# premis Description: MTA - RED LINE - PERSHING SQUARE
# premis Description: MTA - RED LINE - UNION STATION
# premis Description: MTA - RED LINE - UNIVERSAL CITY/STUDIO CITY
# premis Description: MTA - RED LINE - VERMONT/BEVERLY
# premis Description: MTA - RED LINE - VERMONT/SANTA MONICA
# premis Description: MTA - RED LINE - VERMONT/SUNSET
# premis Description: MTA - RED LINE - WESTLAKE/MACARTHUR PARK
# premis Description: MTA - RED LINE - WILSHIRE/VERMONT
# premis Description: MTA - SILVER LINE - 37TH ST/USC
# premis Description: MTA - SILVER LINE - DOWNTOWN STREET STOPS
# premis Description: MTA - SILVER LINE - HARBOR FWY
# premis Description: MTA - SILVER LINE - HARBOR GATEWAY TRANSIT CTR
# premis Description: MTA - SILVER LINE - LAC/USC MEDICAL CENTER
# premis Description: MTA - SILVER LINE - MANCHESTER
# premis Description: MTA - SILVER LINE - PACIFIC COAST HWY
# premis Description: MTA - SILVER LINE - ROSECRANS
# premis Description: MTA - SILVER LINE - SLAUSON
# premis Description: MTA - SILVER LINE - UNION STATION
# premis Description: MTA BUS
# premis Description: MTA PROPERTY OR PARKING LOT
# premis Description: MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# premis Description: MUNICIPAL BUS LINE INCLUDES LADOT/DASH
# premis Description: MUSCLE BEACH
# premis Description: MUSEUM
# premis Description: NAIL SALON
# premis Description: NIGHT CLUB (OPEN EVENINGS ONLY)
# premis Description: NURSERY/FLOWER SHOP
# premis Description: NURSING/CONVALESCENT/RETIREMENT HOME
# premis Description: OFFICE BUILDING/OFFICE
# premis Description: OIL REFINERY
# premis Description: OPTICAL OFFICE INSIDE STORE OR SUPERMARKET*
# premis Description: OTHER BUSINESS
# premis Description: OTHER INTERSTATE, CHARTER BUS
# premis Description: OTHER PLACE OF WORSHIP
# premis Description: OTHER PREMISE
# premis Description: OTHER RESIDENCE
# premis Description: OTHER RR TRAIN (UNION PAC, SANTE FE ETC
# premis Description: OTHER STORE
# premis Description: OTHER/OUTSIDE
# premis Description: PARK/PLAYGROUND
# premis Description: PARKING LOT
# premis Description: PARKING UNDERGROUND/BUILDING
# premis Description: PATIO*
# premis Description: PAWN SHOP
# premis Description: PAY PHONE
# premis Description: PEDESTRIAN OVERCROSSING
# premis Description: PET STORE
# premis Description: PHARMACY INSIDE STORE OR SUPERMARKET*
# premis Description: POLICE FACILITY
# premis Description: POOL-PUBLIC/OUTDOOR OR INDOOR*
# premis Description: PORCH, RESIDENTIAL
# premis Description: POST OFFICE
# premis Description: PRIVATE SCHOOL/PRESCHOOL
# premis Description: PROJECT/TENEMENT/PUBLIC HOUSING
# premis Description: PUBLIC RESTROOM(INDOORS-INSIDE)
# premis Description: PUBLIC RESTROOM/OUTSIDE*
# premis Description: PUBLIC STORAGE
# premis Description: RECORD-CD MUSIC/COMPUTER GAME STORE
# premis Description: RECYCLING CENTER
# premis Description: RESTAURANT/FAST FOOD
# premis Description: RETIRED (DUPLICATE) DO NOT USE THIS CODE
# premis Description: RIVER BED*
# premis Description: SAVINGS & LOAN
# premis Description: SEWAGE FACILITY/PIPE
# premis Description: SEX ORIENTED/BOOK STORE/STRIP CLUB/GENTLEMAN'S CLUB
# premis Description: SHOPPING MALL (COMMON AREA)
# premis Description: SHORT-TERM VACATION RENTAL
# premis Description: SIDEWALK
# premis Description: SINGLE FAMILY DWELLING
# premis Description: SINGLE RESIDENCE OCCUPANCY (SRO'S) LOCATIONS
# premis Description: SKATEBOARD FACILITY/SKATEBOARD PARK*
# premis Description: SKATING RINK*
# premis Description: SLIPS/DOCK/MARINA/BOAT
# premis Description: SPECIALTY SCHOOL/OTHER
# premis Description: SPORTS ARENA
# premis Description: SPORTS VENUE, OTHER
# premis Description: STAIRWELL*
# premis Description: STAPLES CENTER *
# premis Description: STORAGE SHED
# premis Description: STREET
# premis Description: STUDIO (FILM/PHOTOGRAPHIC/MUSIC)
# premis Description: SURPLUS SURVIVAL STORE
# premis Description: SWAP MEET
# premis Description: SYNAGOGUE/TEMPLE
# premis Description: TATTOO PARLOR*
# premis Description: TAXI
# premis Description: TELECOMMUNICATION FACILITY/LOCATION
# premis Description: TERMINAL, OTHER THAN MTA
# premis Description: THE BEVERLY CENTER
# premis Description: THE BEVERLY CONNECTION
# premis Description: THE GROVE
# premis Description: THEATRE/MOVIE
# premis Description: TOBACCO SHOP
# premis Description: TOOL SHED*
# premis Description: TOW YARD*
# premis Description: TRADE SCHOOL (MEDICAL-TECHNICAL-BUSINESS)*
# premis Description: TRAIN DEPOT/TERMINAL, OTHER THAN MTA
# premis Description: TRAIN TRACKS
# premis Description: TRAIN, OTHER THAN MTA (ALSO QUERY 809/810/811)
# premis Description: TRAM/STREETCAR(BOXLIKE WAG ON RAILS)*
# premis Description: TRANSIENT ENCAMPMENT
# premis Description: TRANSITIONAL HOUSING/HALFWAY HOUSE
# premis Description: TRANSPORTATION FACILITY (AIRPORT)
# premis Description: TRASH CAN/TRASH DUMPSTER
# premis Description: TRUCK, COMMERICAL
# premis Description: TUNNEL
# premis Description: TV/RADIO/APPLIANCE
# premis Description: UNDERPASS/BRIDGE*
# premis Description: VACANT LOT
# premis Description: VALET
# premis Description: VEHICLE STORAGE LOT (CARS, TRUCKS, RV'S, BOATS, TRAILERS, ETC.)
# premis Description: VEHICLE, PASSENGER/TRUCK
# premis Description: VETERINARIAN/ANIMAL HOSPITAL
# premis Description: VIDEO RENTAL STORE
# premis Description: VISION CARE FACILITY*
# premis Description: WAREHOUSE
# premis Description: WATER FACILITY
# premis Description: WEBSITE
# premis Description: YARD (RESIDENTIAL/BUSINESS)

# %%
# Checking the number of Status descriptions.
premis = LACrime["Status Desc"].nunique()
premis
# Out:
# 6

# %%
# Group the data by 'Status descriptions'
grouped = LACrime.groupby('Status Desc')

# Iterate through the groups and display different Status Desc
for status, group in grouped:
    print(f"Status Description: {status}")
# Out:
# Status Description: Adult Arrest
# Status Description: Adult Other
# Status Description: Invest Cont
# Status Description: Juv Arrest
# Status Description: Juv Other
# Status Description: UNK

# %%
# remove unnessary columns : 
columns_to_drop = ["Date Rptd", "TIME OCC", "Part 1-2", "Mocodes", "Crm Cd 1", "Crm Cd 2", "Crm Cd 3", "Crm Cd 4", "Cross Street"]
dropped_LAcrime_df = LACrime.drop(columns=columns_to_drop)
dropped_LAcrime_df.head()
# Out:
#        DR_NO                DATE OCC  AREA    AREA NAME  Rpt Dist No  Crm Cd  \
# 0   10304468  01/08/2020 12:00:00 AM     3    Southwest          377     624
# 1  190101086  01/01/2020 12:00:00 AM     1      Central          163     624
# 2  200110444  02/13/2020 12:00:00 AM     1      Central          155     845
# 3  191501505  01/01/2020 12:00:00 AM    15  N Hollywood         1543     745
# 4  191921269  01/01/2020 12:00:00 AM    19      Mission         1998     740
#
#                                          Crm Cd Desc  Vict Age Vict Sex  \
# 0                           BATTERY - SIMPLE ASSAULT        36        F
# 1                           BATTERY - SIMPLE ASSAULT        25        M
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE         0        X
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        76        F
# 4  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        31        X
#
#   Vict Descent  Premis Cd                                   Premis Desc  \
# 0            B      501.0                        SINGLE FAMILY DWELLING
# 1            H      102.0                                      SIDEWALK
# 2            X      726.0                               POLICE FACILITY
# 3            W      502.0  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)
# 4            X      409.0                           BEAUTY SUPPLY STORE
#
#    Weapon Used Cd                                     Weapon Desc Status  \
# 0           400.0  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO
# 1           500.0                     UNKNOWN WEAPON/OTHER WEAPON     IC
# 2             NaN                                             NaN     AA
# 3             NaN                                             NaN     IC
# 4             NaN                                             NaN     IC
#
#     Status Desc                                  LOCATION      LAT       LON
# 0   Adult Other   1100 W  39TH                         PL  34.0141 -118.2978
# 1   Invest Cont    700 S  HILL                         ST  34.0459 -118.2545
# 2  Adult Arrest    200 E  6TH                          ST  34.0448 -118.2474
# 3   Invest Cont   5400    CORTEEN                      PL  34.1685 -118.4019
# 4   Invest Cont  14400    TITUS                        ST  34.2198 -118.4468

# %%
# remove 2023 crime record from the data set because it is only update to Oct. 2023
# First, convert 'date_column' to a datetime format
# dropped_LAcrime_df["DATE OCC"] = pd.to_datetime(dropped_LAcrime_df["DATE OCC"], format="%m/%d/%Y %I:%M:%S %p")

# Filter the DataFrame to keep only the rows with a year other than 2023
# dropped_LAcrime_filtered = dropped_LAcrime_df[dropped_LAcrime_df["DATE OCC"].dt.year != 2023]
# dropped_LAcrime_filtered

# %%
# remove missing values rows in column Vict Descent, Premis Desc
# Make a copy of the DataFrame
dropNA_df = dropped_LAcrime_df.copy()

dropNA_df.dropna(subset=['Vict Descent', 'Premis Desc'], inplace=True)
dropNA_df
# Out:
#             DR_NO                DATE OCC  AREA    AREA NAME  Rpt Dist No  \
# 0        10304468  01/08/2020 12:00:00 AM     3    Southwest          377
# 1       190101086  01/01/2020 12:00:00 AM     1      Central          163
# 2       200110444  02/13/2020 12:00:00 AM     1      Central          155
# 3       191501505  01/01/2020 12:00:00 AM    15  N Hollywood         1543
# 4       191921269  01/01/2020 12:00:00 AM    19      Mission         1998
# ...           ...                     ...   ...          ...          ...
# 811658  231604807  01/26/2023 12:00:00 AM    16     Foothill         1663
# 811659  231606525  03/22/2023 12:00:00 AM    16     Foothill         1602
# 811660  231210064  04/12/2023 12:00:00 AM    12  77th Street         1239
# 811661  230115220  07/01/2023 12:00:00 AM     1      Central          154
# 811662  230906458  03/05/2023 12:00:00 AM     9     Van Nuys          914
#
#         Crm Cd                                        Crm Cd Desc  Vict Age  \
# 0          624                           BATTERY - SIMPLE ASSAULT        36
# 1          624                           BATTERY - SIMPLE ASSAULT        25
# 2          845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE         0
# 3          745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        76
# 4          740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        31
# ...        ...                                                ...       ...
# 811658     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        23
# 811659     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25
# 811660     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        29
# 811661     352                                         PICKPOCKET        24
# 811662     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        53
#
#        Vict Sex Vict Descent  Premis Cd  \
# 0             F            B      501.0
# 1             M            H      102.0
# 2             X            X      726.0
# 3             F            W      502.0
# 4             X            X      409.0
# ...         ...          ...        ...
# 811658        M            H      122.0
# 811659        F            H      102.0
# 811660        M            B      222.0
# 811661        F            H      735.0
# 811662        F            H      502.0
#
#                                          Premis Desc  Weapon Used Cd  \
# 0                             SINGLE FAMILY DWELLING           400.0
# 1                                           SIDEWALK           500.0
# 2                                    POLICE FACILITY             NaN
# 3       MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
# 4                                BEAUTY SUPPLY STORE             NaN
# ...                                              ...             ...
# 811658                      VEHICLE, PASSENGER/TRUCK             NaN
# 811659                                      SIDEWALK           400.0
# 811660                                    LAUNDROMAT           500.0
# 811661               NIGHT CLUB (OPEN EVENINGS ONLY)             NaN
# 811662  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
#
#                                            Weapon Desc Status   Status Desc  \
# 0       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO   Adult Other
# 1                          UNKNOWN WEAPON/OTHER WEAPON     IC   Invest Cont
# 2                                                  NaN     AA  Adult Arrest
# 3                                                  NaN     IC   Invest Cont
# 4                                                  NaN     IC   Invest Cont
# ...                                                ...    ...           ...
# 811658                                             NaN     IC   Invest Cont
# 811659  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC   Invest Cont
# 811660                     UNKNOWN WEAPON/OTHER WEAPON     IC   Invest Cont
# 811661                                             NaN     IC   Invest Cont
# 811662                                             NaN     IC   Invest Cont
#
#                                         LOCATION      LAT       LON
# 0        1100 W  39TH                         PL  34.0141 -118.2978
# 1         700 S  HILL                         ST  34.0459 -118.2545
# 2         200 E  6TH                          ST  34.0448 -118.2474
# 3        5400    CORTEEN                      PL  34.1685 -118.4019
# 4       14400    TITUS                        ST  34.2198 -118.4468
# ...                                          ...      ...       ...
# 811658  12500    BRANFORD                     ST  34.2466 -118.4054
# 811659  12800    FILMORE                      ST  34.2790 -118.4116
# 811660   6100 S  VERMONT                      AV  33.9841 -118.2915
# 811661    500 S  MAIN                         ST  34.0467 -118.2485
# 811662  14500    HARTLAND                     ST  34.1951 -118.4487
#
# [704662 rows x 19 columns]

# %%
# Drop rows where any cell in the row contains "-"
dropNA_df = dropNA_df[~(dropNA_df == "-").any(axis=1)]
dropNA_df
# Out:
#             DR_NO                DATE OCC  AREA    AREA NAME  Rpt Dist No  \
# 0        10304468  01/08/2020 12:00:00 AM     3    Southwest          377
# 1       190101086  01/01/2020 12:00:00 AM     1      Central          163
# 2       200110444  02/13/2020 12:00:00 AM     1      Central          155
# 3       191501505  01/01/2020 12:00:00 AM    15  N Hollywood         1543
# 4       191921269  01/01/2020 12:00:00 AM    19      Mission         1998
# ...           ...                     ...   ...          ...          ...
# 811658  231604807  01/26/2023 12:00:00 AM    16     Foothill         1663
# 811659  231606525  03/22/2023 12:00:00 AM    16     Foothill         1602
# 811660  231210064  04/12/2023 12:00:00 AM    12  77th Street         1239
# 811661  230115220  07/01/2023 12:00:00 AM     1      Central          154
# 811662  230906458  03/05/2023 12:00:00 AM     9     Van Nuys          914
#
#         Crm Cd                                        Crm Cd Desc  Vict Age  \
# 0          624                           BATTERY - SIMPLE ASSAULT        36
# 1          624                           BATTERY - SIMPLE ASSAULT        25
# 2          845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE         0
# 3          745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        76
# 4          740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        31
# ...        ...                                                ...       ...
# 811658     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        23
# 811659     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25
# 811660     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        29
# 811661     352                                         PICKPOCKET        24
# 811662     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        53
#
#        Vict Sex Vict Descent  Premis Cd  \
# 0             F            B      501.0
# 1             M            H      102.0
# 2             X            X      726.0
# 3             F            W      502.0
# 4             X            X      409.0
# ...         ...          ...        ...
# 811658        M            H      122.0
# 811659        F            H      102.0
# 811660        M            B      222.0
# 811661        F            H      735.0
# 811662        F            H      502.0
#
#                                          Premis Desc  Weapon Used Cd  \
# 0                             SINGLE FAMILY DWELLING           400.0
# 1                                           SIDEWALK           500.0
# 2                                    POLICE FACILITY             NaN
# 3       MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
# 4                                BEAUTY SUPPLY STORE             NaN
# ...                                              ...             ...
# 811658                      VEHICLE, PASSENGER/TRUCK             NaN
# 811659                                      SIDEWALK           400.0
# 811660                                    LAUNDROMAT           500.0
# 811661               NIGHT CLUB (OPEN EVENINGS ONLY)             NaN
# 811662  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)             NaN
#
#                                            Weapon Desc Status   Status Desc  \
# 0       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO   Adult Other
# 1                          UNKNOWN WEAPON/OTHER WEAPON     IC   Invest Cont
# 2                                                  NaN     AA  Adult Arrest
# 3                                                  NaN     IC   Invest Cont
# 4                                                  NaN     IC   Invest Cont
# ...                                                ...    ...           ...
# 811658                                             NaN     IC   Invest Cont
# 811659  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC   Invest Cont
# 811660                     UNKNOWN WEAPON/OTHER WEAPON     IC   Invest Cont
# 811661                                             NaN     IC   Invest Cont
# 811662                                             NaN     IC   Invest Cont
#
#                                         LOCATION      LAT       LON
# 0        1100 W  39TH                         PL  34.0141 -118.2978
# 1         700 S  HILL                         ST  34.0459 -118.2545
# 2         200 E  6TH                          ST  34.0448 -118.2474
# 3        5400    CORTEEN                      PL  34.1685 -118.4019
# 4       14400    TITUS                        ST  34.2198 -118.4468
# ...                                          ...      ...       ...
# 811658  12500    BRANFORD                     ST  34.2466 -118.4054
# 811659  12800    FILMORE                      ST  34.2790 -118.4116
# 811660   6100 S  VERMONT                      AV  33.9841 -118.2915
# 811661    500 S  MAIN                         ST  34.0467 -118.2485
# 811662  14500    HARTLAND                     ST  34.1951 -118.4487
#
# [704660 rows x 19 columns]

# %%
# replace blanks values in column Weapon Used Cd, and Weapon Desc with N/A for no weapon used
cleanData = dropNA_df.fillna(value='N/A')
cleanData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 704660 entries, 0 to 811662
# Data columns (total 19 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   DR_NO           704660 non-null  int64
#  1   DATE OCC        704660 non-null  object
#  2   AREA            704660 non-null  int64
#  3   AREA NAME       704660 non-null  object
#  4   Rpt Dist No     704660 non-null  int64
#  5   Crm Cd          704660 non-null  int64
#  6   Crm Cd Desc     704660 non-null  object
#  7   Vict Age        704660 non-null  int64
#  8   Vict Sex        704660 non-null  object
#  9   Vict Descent    704660 non-null  object
#  10  Premis Cd       704660 non-null  float64
#  11  Premis Desc     704660 non-null  object
#  12  Weapon Used Cd  704660 non-null  object
#  13  Weapon Desc     704660 non-null  object
#  14  Status          704660 non-null  object
#  15  Status Desc     704660 non-null  object
#  16  LOCATION        704660 non-null  object
#  17  LAT             704660 non-null  float64
#  18  LON             704660 non-null  float64
# dtypes: float64(3), int64(5), object(11)
# memory usage: 107.5+ MB

# %%
# Check for unrealistic data
cleanData.describe()
# Out:
#               DR_NO           AREA    Rpt Dist No         Crm Cd  \
# count  7.046600e+05  704660.000000  704660.000000  704660.000000
# mean   2.159605e+08      10.651963    1111.545266     501.304455
# std    1.076681e+07       6.112232     611.132561     222.351730
# min    1.030447e+07       1.000000     101.000000     110.000000
# 25%    2.101193e+08       6.000000     621.000000     330.000000
# 50%    2.201119e+08      11.000000    1132.000000     440.000000
# 75%    2.219100e+08      16.000000    1612.000000     661.000000
# max    2.399165e+08      21.000000    2199.000000     956.000000
#
#             Vict Age      Premis Cd            LAT            LON
# count  704660.000000  704660.000000  704660.000000  704660.000000
# mean       34.346989     332.879502      33.969206    -117.989915
# std        19.762148     215.664554       1.893348       6.566159
# min        -3.000000     101.000000       0.000000    -118.667600
# 25%        23.000000     108.000000      34.015300    -118.431200
# 50%        34.000000     401.000000      34.059300    -118.323600
# 75%        48.000000     502.000000      34.163000    -118.274000
# max        99.000000     971.000000      34.334300       0.000000

# %%
# Clean unrealistic data found in "Vict Age" with -values
cleanData.drop(cleanData[cleanData["Vict Age"] < 0].index, axis=0, inplace=True)
cleanData
# Out:
#             DR_NO                DATE OCC  AREA    AREA NAME  Rpt Dist No  \
# 0        10304468  01/08/2020 12:00:00 AM     3    Southwest          377
# 1       190101086  01/01/2020 12:00:00 AM     1      Central          163
# 2       200110444  02/13/2020 12:00:00 AM     1      Central          155
# 3       191501505  01/01/2020 12:00:00 AM    15  N Hollywood         1543
# 4       191921269  01/01/2020 12:00:00 AM    19      Mission         1998
# ...           ...                     ...   ...          ...          ...
# 811658  231604807  01/26/2023 12:00:00 AM    16     Foothill         1663
# 811659  231606525  03/22/2023 12:00:00 AM    16     Foothill         1602
# 811660  231210064  04/12/2023 12:00:00 AM    12  77th Street         1239
# 811661  230115220  07/01/2023 12:00:00 AM     1      Central          154
# 811662  230906458  03/05/2023 12:00:00 AM     9     Van Nuys          914
#
#         Crm Cd                                        Crm Cd Desc  Vict Age  \
# 0          624                           BATTERY - SIMPLE ASSAULT        36
# 1          624                           BATTERY - SIMPLE ASSAULT        25
# 2          845          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE         0
# 3          745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        76
# 4          740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        31
# ...        ...                                                ...       ...
# 811658     740  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        23
# 811659     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        25
# 811660     230     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        29
# 811661     352                                         PICKPOCKET        24
# 811662     745           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        53
#
#        Vict Sex Vict Descent  Premis Cd  \
# 0             F            B      501.0
# 1             M            H      102.0
# 2             X            X      726.0
# 3             F            W      502.0
# 4             X            X      409.0
# ...         ...          ...        ...
# 811658        M            H      122.0
# 811659        F            H      102.0
# 811660        M            B      222.0
# 811661        F            H      735.0
# 811662        F            H      502.0
#
#                                          Premis Desc Weapon Used Cd  \
# 0                             SINGLE FAMILY DWELLING          400.0
# 1                                           SIDEWALK          500.0
# 2                                    POLICE FACILITY            N/A
# 3       MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)            N/A
# 4                                BEAUTY SUPPLY STORE            N/A
# ...                                              ...            ...
# 811658                      VEHICLE, PASSENGER/TRUCK            N/A
# 811659                                      SIDEWALK          400.0
# 811660                                    LAUNDROMAT          500.0
# 811661               NIGHT CLUB (OPEN EVENINGS ONLY)            N/A
# 811662  MULTI-UNIT DWELLING (APARTMENT, DUPLEX, ETC)            N/A
#
#                                            Weapon Desc Status   Status Desc  \
# 0       STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     AO   Adult Other
# 1                          UNKNOWN WEAPON/OTHER WEAPON     IC   Invest Cont
# 2                                                  N/A     AA  Adult Arrest
# 3                                                  N/A     IC   Invest Cont
# 4                                                  N/A     IC   Invest Cont
# ...                                                ...    ...           ...
# 811658                                             N/A     IC   Invest Cont
# 811659  STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)     IC   Invest Cont
# 811660                     UNKNOWN WEAPON/OTHER WEAPON     IC   Invest Cont
# 811661                                             N/A     IC   Invest Cont
# 811662                                             N/A     IC   Invest Cont
#
#                                         LOCATION      LAT       LON
# 0        1100 W  39TH                         PL  34.0141 -118.2978
# 1         700 S  HILL                         ST  34.0459 -118.2545
# 2         200 E  6TH                          ST  34.0448 -118.2474
# 3        5400    CORTEEN                      PL  34.1685 -118.4019
# 4       14400    TITUS                        ST  34.2198 -118.4468
# ...                                          ...      ...       ...
# 811658  12500    BRANFORD                     ST  34.2466 -118.4054
# 811659  12800    FILMORE                      ST  34.2790 -118.4116
# 811660   6100 S  VERMONT                      AV  33.9841 -118.2915
# 811661    500 S  MAIN                         ST  34.0467 -118.2485
# 811662  14500    HARTLAND                     ST  34.1951 -118.4487
#
# [704592 rows x 19 columns]

# %%
cleanData.describe()
# Out:
#               DR_NO           AREA    Rpt Dist No         Crm Cd  \
# count  7.045920e+05  704592.000000  704592.000000  704592.000000
# mean   2.159594e+08      10.651898    1111.539011     501.296985
# std    1.076664e+07       6.112234     611.132692     222.351391
# min    1.030447e+07       1.000000     101.000000     110.000000
# 25%    2.101192e+08       6.000000     621.000000     330.000000
# 50%    2.201119e+08      11.000000    1132.000000     440.000000
# 75%    2.219100e+08      16.000000    1612.000000     661.000000
# max    2.399165e+08      21.000000    2199.000000     956.000000
#
#             Vict Age      Premis Cd            LAT            LON
# count  704592.000000  704592.000000  704592.000000  704592.000000
# mean       34.350420     332.874148      33.969194    -117.989879
# std        19.760014     215.662499       1.893438       6.566475
# min         0.000000     101.000000       0.000000    -118.667600
# 25%        23.000000     108.000000      34.015300    -118.431200
# 50%        34.000000     401.000000      34.059300    -118.323600
# 75%        48.000000     502.000000      34.163000    -118.274000
# max        99.000000     971.000000      34.334300       0.000000

# %%
# Vict age comparison into 8 different groups
# Define the bins and labels
bins = [0, 18, 25, 35, 45, 55, 65, 100]  # You can adjust these bin boundaries as needed
labels = ["0-18", "19-25", "26-35", "36-45", "46-55", "56-65", "66+"]

# Use pd.cut() to create the age groups
cleanData["AgeGroup"] = pd.cut(cleanData["Vict Age"], bins=bins, labels=labels)

# Count the occurrences of each age group
age_group_counts = cleanData["AgeGroup"].value_counts().reindex(labels)

# Create a bar plot
plt.figure(figsize=(6, 4))
plt.bar(age_group_counts.index, age_group_counts, width=0.75)

# Set plot labels and title
plt.xlabel("Age Group")
plt.ylabel("Count")
plt.title("Distribution of Victim Ages by Age Group")

# Rotate x-axis labels by 45 degrees for better readability
plt.xticks(rotation=45)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Replace "H" and "M" to "Male"
cleanData["Vict Sex"] = cleanData["Vict Sex"].replace(["H", "M"], "Male")
cleanData["Vict Sex"] = cleanData["Vict Sex"].replace(["F"], "Female")
cleanData["Vict Sex"] = cleanData["Vict Sex"].replace(["X", "N/A"], "Unknow")

# Group the data by "Vict Sex"
grouped = cleanData.groupby("Vict Sex")

# Count the occurrences of each gender category
gender_counts = grouped.size()

# Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(gender_counts, labels=gender_counts.index, autopct="%1.1f%%", startangle=140)

# Set plot title
plt.title("Distribution of Gender Types")

# Show the pie chart
plt.axis("equal")  # Equal aspect ratio ensures that the pie chart is circular.

plt.tight_layout()
plt.show()

# %%
# Group "Vict Descent" into 5 groups 
cleanData["Vict Descent"] = cleanData["Vict Descent"].replace(["A", "C", "J", "K", "V", "Z"], "Asian")
cleanData["Vict Descent"] = cleanData["Vict Descent"].replace(["B"], "Black")
cleanData["Vict Descent"] = cleanData["Vict Descent"].replace(["H"], "Hispanic/Latin/Mexican")
cleanData["Vict Descent"] = cleanData["Vict Descent"].replace(["D", "F", "L", "O", "G", "P", "S", "U"], "Other")
cleanData["Vict Descent"] = cleanData["Vict Descent"].replace(["I", "W", "X"], "White")

# Group the data by "Vict Descent"
grouped = cleanData.groupby("Vict Descent")

# Count the occurrences of each Race category
race_counts = grouped.size()

# Sort the data by counts in ascending order
race_counts_sorted = race_counts.sort_values(ascending=False)

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(race_counts_sorted, labels=race_counts_sorted.index, autopct="%1.1f%%", startangle=0)

# Set plot title
plt.title("Distribution of Race Types")

# Show the pie chart
plt.axis("equal")  # Equal aspect ratio ensures that the pie chart is circular.

plt.tight_layout()
plt.show()

# %%
# Area Crime committed data analysis use "AREA NAME"
# Group the data by 'AREA NAME'
grouped = cleanData.groupby('AREA NAME')

# Count the occurrences of each area
area_counts = grouped.size()

# Sort the data by counts in ascending order
area_counts_sorted = area_counts.sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(10, 4))
plt.bar(area_counts.index, area_counts_sorted, color="b", align="center", width=0.75)

# Set plot labels and title
plt.xlabel("Los Angeles Areas")
plt.ylabel("Crime Count")
plt.title("Distribution of different area")

# Rotate x-axis labels by 45 degrees for better readability
plt.xticks(rotation=90)
plt.xlim(-0.75, len(area_counts)-0.25)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Group "Weapon Desc" into 6 groups 
cleanData["Weapon Desc"] = cleanData["Weapon Desc"].replace(["ANTIQUE FIREARM", "AUTOMATIC WEAPON/SUB-MACHINE GUN",
                                                             "HAND GUN", "HECKLER & KOCH 91 SEMIAUTOMATIC ASSAULT RIFLE",
                                                             "HECKLER & KOCH 93 SEMIAUTOMATIC ASSAULT RIFLE", 
                                                             "M-14 SEMIAUTOMATIC ASSAULT RIFLE",
                                                             "M1-1 SEMIAUTOMATIC ASSAULT RIFLE",
                                                             "MAC-10 SEMIAUTOMATIC ASSAULT WEAPON",
                                                             "MAC-11 SEMIAUTOMATIC ASSAULT WEAPON", "RELIC FIREARM",
                                                             "REVOLVER", "RIFLE", "SAWED OFF RIFLE/SHOTGUN",
                                                             "SEMI-AUTOMATIC PISTOL", "SEMI-AUTOMATIC RIFLE", "SHOTGUN", 
                                                             "UNK TYPE SEMIAUTOMATIC ASSAULT RIFLE",
                                                             "UNKNOWN FIREARM", "AIR PISTOL/REVOLVER/RIFLE/BB GUN", 
                                                             "ASSAULT WEAPON/UZI/AK47/ETC", "OTHER FIREARM", 
                                                             "UZI SEMIAUTOMATIC ASSAULT RIFLE", "BOMB THREAT",
                                                             "CAUSTIC CHEMICAL/POISON", "EXPLOXIVE DEVICE", "FIRE", 
                                                             "LIQUOR/DRUGS", "SCALDING LIQUID", "SYRINGE"], 
                                                            "Gun/Firearm/Chemical Explosive")

cleanData["Weapon Desc"] = cleanData["Weapon Desc"].replace(["BOWIE KNIFE", "CLEAVER", "DIRK DAGGER", "FOLDING KNIFE",
                                                             "KITCHEN KNIFE", "KNIFE WITH BLADE 6INCHES OR LESS",
                                                             "KNIFE WITH BLADE OVER 6 INCHES IN LENGTH", "RAZOR",
                                                             "STRAIGHT RAZOR", "SWORD", "UNKNOWN TYPE CUTTING INSTRUMENT",
                                                             "MACHETE", "ICE PICK", "OTHER CUTTING INSTRUMENT",
                                                             "OTHER KNIFE", "DIRK/DAGGER", "RAZOR BLADE", "SCISSORS", 
                                                             "SCREWDRIVER", "SWITCH BLADE", "BOW AND ARROW"],
                                                            "Knife/Sharp Object")

cleanData["Weapon Desc"] = cleanData["Weapon Desc"].replace(["AXE", "BELT FLAILING INSTRUMENT CHAIN", "BLACKJACK",
                                                             "BLUNT INSTRUMENT", "BOARD", "BRASS KNUCKLES", "CLUB/BAT",
                                                             "CONCRETE BLOCK/BRICK", "GLASS", "HAMMER", "PIPE METAL PIPE",
                                                             "ROCK/THROWN OBJECT", "STICK", "UNKNOWN WEAPON OTHER WEAPON", 
                                                             "FIXED OBJECT", "BOTTLE", "PIPE/METAL PIPE", ""], 
                                                            "Blunt Objects")
  
cleanData["Weapon Desc"] = cleanData["Weapon Desc"].replace(["MARTIAL ARTS WEAPONS", "PHYSICAL PRESENCE", 
                                                             "STRONG-ARM (HANDS, FIST, FEET OR BODILY FORCE)"],
                                                            "Personal Weapons")
    
cleanData["Weapon Desc"] = cleanData["Weapon Desc"].replace(["VEHICLE", "AIR PISTOL REVOLVER RIFLE BB GUN", "STARTER PISTOL/REVOLVER", 
                                                             "TOY GUN", "UNKNOWN TYPE SEMIAUTOMATIC ASSAULT RIFLE", 
                                                             "SIMULATED GUN", "TIRE IRON", "BELT FLAILING INSTRUMENT/CHAIN", "ROPE/LIGATURE", 
                                                             "UNKNOWN WEAPON/OTHER WEAPON", "MACE/PEPPER SPRAY", "STUN GUN",
                                                             "DOG/ANIMAL (SIC ANIMAL ON)", "VERBAL THREAT", "DEMAND NOTE"], 
                                                            "Other Weapon")

cleanData["Weapon Desc"] = cleanData["Weapon Desc"].replace(["N/A"], "No Weapon Used")

# Group the data by "Weapon Desc"
groupe = cleanData.groupby("Weapon Desc")

# Count the occurrences of each weapon type used
weapon_count = groupe.size()

# Sort the data by counts in ascending order
weapon_count_sorted = weapon_count.sort_values(ascending=False)

# Create a bar plot
plt.figure(figsize=(6, 6))
plt.bar(weapon_count_sorted.index, weapon_count_sorted, color="b", align="center", width=0.75)

# Set plot labels and title
plt.xlabel("Type of Weapon Used")
plt.ylabel("Count")
plt.title("Type of Weapon Used Comparison Chart")

# Rotate x-axis labels by 45 degrees for better readability
plt.xticks(rotation=45, rotation_mode="anchor", ha="right", wrap=True)
plt.xlim(-0.75, len(weapon_count)-0.25)

# Show the plot
plt.tight_layout()
plt.show()

# %%
# Create a pie chart
plt.figure(figsize=(6, 6))

# Adjust the labeldistance to move the labels outward
labeldistance = 1.1  # You can adjust this value to control the label distance

# Set the font size for the labels (textprops argument)
label_font = {"fontsize": 8}  # You can adjust the fontsize as needed

plt.pie(weapon_count_sorted, labels=weapon_count_sorted.index, autopct="%1.1f%%", startangle=140, labeldistance=labeldistance, textprops=label_font)

# Set plot title
plt.title("Type of Weapon Used Comparison Chart")

# Show the pie chart
plt.axis("equal")  # Equal aspect ratio ensures that the pie chart is circular.

plt.tight_layout()
plt.show()

# %%
# Group
cleanData["Status Desc"] = cleanData["Status Desc"].replace(["Juv Arrest", "Juv Other"], "Juvenile Arrest")
cleanData["Status Desc"] = cleanData["Status Desc"].replace(["Adult Arrest", "Adult Other"], "Adult Arrest")
cleanData["Status Desc"] = cleanData["Status Desc"].replace(["UNK", "Invest Cont"], "Invest Cont")

# Group the data by 'Status Desc'
grouped = cleanData.groupby("Status Desc")

# Count the occurrences of current status
status_counts = grouped.size()

# Create a pie chart
plt.figure(figsize=(6, 6))
plt.pie(status_counts, labels=status_counts.index, autopct="%1.1f%%", startangle=140)

# Set plot title
plt.title("Distribution of Status")

# Show the pie chart
plt.axis("equal")  # Equal aspect ratio ensures that the pie chart is circular.

plt.tight_layout()
plt.show()

# %%
# Group the data by 'Crm Cd Desc' and count the occurrences
crime_type_counts = cleanData["Crm Cd Desc"].value_counts()

# Identify crime types with counts less than 2500
low_count_crime_types = crime_type_counts[crime_type_counts < 2500].index

# Replace those crime types with "Other" in a new column
cleanData["Crm Cd Desc Grouped"] = cleanData["Crm Cd Desc"].apply(lambda x: "Other" if x in low_count_crime_types else x)

# Group the data by the new column and sum the counts
grouped_data = cleanData["Crm Cd Desc Grouped"].value_counts()

# Create a pie chart
plt.figure(figsize=(20, 20))
plt.pie(grouped_data, labels=grouped_data.index, autopct="%1.1f%%", startangle=180)

# Set plot title
plt.title("Distribution of Different Crime Types (Including 'Other')")

# Show the pie chart
plt.axis("equal")  # Equal aspect ratio ensures that the pie chart is circular.

plt.tight_layout()
plt.show()

# %%
# Make sure you have the "DATE OCC" column as a datetime object
cleanData["DATE OCC"] = pd.to_datetime(cleanData["DATE OCC"], format="%m/%d/%Y %I:%M:%S %p")

# Extract year and month from the "DATE OCC" column
cleanData["Year"] = cleanData["DATE OCC"].dt.year
cleanData["Month"] = cleanData["DATE OCC"].dt.month

# Filter data for the years 2020, 2021, 2022, and 2023
years_to_compare = [2020, 2021, 2022, 2023]
filtered_data = cleanData[cleanData["Year"].isin(years_to_compare)]

# Group the data by year and month and count the number of occurrences
monthly_counts = filtered_data.groupby(["Year", "Month"]).size().unstack().fillna(0)

# Create a line chart to compare data by month
plt.figure(figsize=(12, 6))
for year in years_to_compare:
    plt.plot(monthly_counts.loc[year], label=f"Year {year}")

# Set chart labels and title
plt.xlabel("Month")
plt.ylabel("Number of Incidents")
plt.title("Crime Incidents Comparison by Month (2020, 2021, 2022, 2023)")

# Add a legend to distinguish the years
plt.legend()

# Show the plot
plt.grid(True)
plt.tight_layout()
plt.show()
