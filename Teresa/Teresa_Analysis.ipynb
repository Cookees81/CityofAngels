# %%
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
lapd_one = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-1.csv')
lapd_two = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-2.csv') 
lapd_three = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-3.csv') 
lapd_four = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-4.csv')
lapd_five = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-5.csv')
lapd_six = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-6.csv')
lapd_seven = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-7.csv')
lapd_eight = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-8.csv') 
lapd_nine = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-9.csv')
lapd_ten = pd.read_csv('LAPD Crime_Data_from_2020_to_Present (2)-10.csv')

# %%
lapd_one.head()
# Out:
#        DR_NO     Date Rptd      DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0   10304468   1/8/20 0:00   1/8/20 0:00      2230     3    Southwest
# 1  190101086   1/2/20 0:00   1/1/20 0:00       330     1      Central
# 2  200110444  4/14/20 0:00  2/13/20 0:00      1200     1      Central
# 3  191501505   1/1/20 0:00   1/1/20 0:00      1730    15  N Hollywood
# 4  191921269   1/1/20 0:00   1/1/20 0:00       415    19      Mission
#
#    Rpt Dist No  Part 1-2  Crm Cd  \
# 0          377         2     624
# 1          163         2     624
# 2          155         2     845
# 3         1543         2     745
# 4         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# ...

# %%
lapd_one.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81167 entries, 0 to 81166
# Data columns (total 28 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   DR_NO           81167 non-null  int64
#  1   Date Rptd       81167 non-null  object
#  2   DATE OCC        81167 non-null  object
#  3   TIME OCC        81167 non-null  int64
#  4   AREA            81167 non-null  int64
#  5   AREA NAME       81167 non-null  object
#  6   Rpt Dist No     81167 non-null  int64
#  7   Part 1-2        81167 non-null  int64
#  8   Crm Cd          81167 non-null  int64
#  9   Crm Cd Desc     81167 non-null  object
#  10  Mocodes         72055 non-null  object
#  11  Vict Age        81167 non-null  int64
#  12  Vict Sex        72401 non-null  object
#  13  Vict Descent    72398 non-null  object
#  14  Premis Cd       81166 non-null  float64
#  15  Premis Desc     81141 non-null  object
#  16  Weapon Used Cd  27944 non-null  float64
# ...

# %%
# print one.append([two,one,two])
# pd.concat([one,two],keys=['x','y'],ignore_index=True)
summary_lapd = pd.concat([lapd_one, lapd_two, lapd_three, lapd_four, lapd_five, lapd_six, 
                        lapd_seven, lapd_eight, lapd_nine, lapd_ten],keys=['a','b','c','d','e','f','g','h','i','j'],
                              ignore_index=True)
summary_lapd.head()
# Out:
#        DR_NO     Date Rptd      DATE OCC  TIME OCC  AREA    AREA NAME  \
# 0   10304468   1/8/20 0:00   1/8/20 0:00      2230     3    Southwest
# 1  190101086   1/2/20 0:00   1/1/20 0:00       330     1      Central
# 2  200110444  4/14/20 0:00  2/13/20 0:00      1200     1      Central
# 3  191501505   1/1/20 0:00   1/1/20 0:00      1730    15  N Hollywood
# 4  191921269   1/1/20 0:00   1/1/20 0:00       415    19      Mission
#
#    Rpt Dist No  Part 1-2  Crm Cd  \
# 0          377         2     624
# 1          163         2     624
# 2          155         2     845
# 3         1543         2     745
# 4         1998         2     740
#
#                                          Crm Cd Desc  ... Status  \
# 0                           BATTERY - SIMPLE ASSAULT  ...     AO
# 1                           BATTERY - SIMPLE ASSAULT  ...     IC
# 2          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE  ...     AA
# 3           VANDALISM - MISDEAMEANOR ($399 OR UNDER)  ...     IC
# ...

# %%
# time_sortedlapd = lapd_one.groupby("TIME OCC")
# time_sortedlapd.head()
# time_one = summary_lapd.groupby(["TIME OCC"].sort_values())
time_crime = summary_lapd[["TIME OCC", "AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent",
                             "Status Desc", "LAT", "LON"]]
time_crime.head()
# Out:
#    TIME OCC    AREA NAME                                        Crm Cd Desc  \
# 0      2230    Southwest                           BATTERY - SIMPLE ASSAULT
# 1       330      Central                           BATTERY - SIMPLE ASSAULT
# 2      1200      Central          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3      1730  N Hollywood           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4       415      Mission  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex Vict Descent   Status Desc      LAT       LON
# 0        36        F            B   Adult Other  34.0141 -118.2978
# 1        25        M            H   Invest Cont  34.0459 -118.2545
# 2         0        X            X  Adult Arrest  34.0448 -118.2474
# 3        76        F            W   Invest Cont  34.1685 -118.4019
# 4        31        X            X   Invest Cont  34.2198 -118.4468

# %%
# Tutorial: Add a Column to a Pandas DataFrame Based on an If-Else Condition from Dataquest online article July 1, 2020
# create a list of our conditions
conditions = [
    (time_crime['TIME OCC'] > 1) & (time_crime['TIME OCC'] <= 59),
    (time_crime['TIME OCC'] >= 100) & (time_crime['TIME OCC'] <= 159),
    (time_crime['TIME OCC'] >= 200) & (time_crime['TIME OCC'] <= 259),
    (time_crime['TIME OCC'] >= 300) & (time_crime['TIME OCC'] <= 359),
    (time_crime['TIME OCC'] >= 400) & (time_crime['TIME OCC'] <= 459),
    (time_crime['TIME OCC'] >= 500) & (time_crime['TIME OCC'] <= 559),
    (time_crime['TIME OCC'] >= 600) & (time_crime['TIME OCC'] <= 659),
    (time_crime['TIME OCC'] >= 700) & (time_crime['TIME OCC'] <= 759),
    (time_crime['TIME OCC'] >= 800) & (time_crime['TIME OCC'] <= 859),
    (time_crime['TIME OCC'] >= 900) & (time_crime['TIME OCC'] <= 959),
    (time_crime['TIME OCC'] >= 1000) & (time_crime['TIME OCC'] <= 1059),
    (time_crime['TIME OCC'] >= 1100) & (time_crime['TIME OCC'] <= 1159),
    (time_crime['TIME OCC'] >= 1200) & (time_crime['TIME OCC'] <= 1259),
    (time_crime['TIME OCC'] >= 1300) & (time_crime['TIME OCC'] <= 1359),
    (time_crime['TIME OCC'] >= 1400) & (time_crime['TIME OCC'] <= 1459),
    (time_crime['TIME OCC'] >= 1500) & (time_crime['TIME OCC'] <= 1559),
    (time_crime['TIME OCC'] >= 1600) & (time_crime['TIME OCC'] <= 1659),
    (time_crime['TIME OCC'] >= 1700) & (time_crime['TIME OCC'] <= 1759),
    (time_crime['TIME OCC'] >= 1800) & (time_crime['TIME OCC'] <= 1859),
    (time_crime['TIME OCC'] >= 1900) & (time_crime['TIME OCC'] <= 1959),
    (time_crime['TIME OCC'] >= 2000) & (time_crime['TIME OCC'] <= 2059),
    (time_crime['TIME OCC'] >= 2100) & (time_crime['TIME OCC'] <= 2159),
    (time_crime['TIME OCC'] >= 2200) & (time_crime['TIME OCC'] <= 2259),
    (time_crime['TIME OCC'] >= 2300) & (time_crime['TIME OCC'] <= 2359)
    ]

# create a list of the values we want to assign for each condition
values = ['0000', '0100', '0200', '0300', '0400', '0500', '0600', '0700', '0800', '0900',
          '1000', '1100', '1200', '1300', '1400', '1500', '1600', '1700', '1800', '1900',
          '2000', ' 2100', '2200', '2300']

# create a new column and use np.select to assign values to it using our lists as arguments
time_crime['Hour'] = np.select(conditions, values)

# >>> df.sort_values(by=['col1'])
#   col1  col2  col3 col4
# 0    A     2     0    a
# 1    A     1     1    B
# 2    B     9     9    c
# 5    C     4     3    F
# 4    D     7     2    e
# 3  NaN     8     4    D
# time_crimesort = time_crime.sort_values(by='TIME OCC')

# display updated DataFrame
time_crime.head()
# Out:
# C:\Users\salaz\AppData\Local\Temp\ipykernel_3440\2673063217.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   time_crime['Hour'] = np.select(conditions, values)
#    TIME OCC    AREA NAME                                        Crm Cd Desc  \
# 0      2230    Southwest                           BATTERY - SIMPLE ASSAULT
# 1       330      Central                           BATTERY - SIMPLE ASSAULT
# 2      1200      Central          SEX OFFENDER REGISTRANT OUT OF COMPLIANCE
# 3      1730  N Hollywood           VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 4       415      Mission  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...
#
#    Vict Age Vict Sex Vict Descent   Status Desc      LAT       LON  Hour
# ...

# %%
crime_timesummary = time_crime.sort_values(by='TIME OCC')
crime_timesummary
# Out:
#         TIME OCC    AREA NAME  \
# 445079         1    Southwest
# 420052         1    Northeast
# 726681         1  77th Street
# 17593          1    Northeast
# 420025         1      Olympic
# ...          ...          ...
# 660968      2359      Topanga
# 770037      2359  N Hollywood
# 477570      2359     Wilshire
# 740638      2359    Hollywood
# 378634      2359     Van Nuys
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 445079                                  THEFT OF IDENTITY        46        F
# 420052                                  THEFT OF IDENTITY        64        M
# 726681                                  THEFT OF IDENTITY        32        M
# 17593                               BURGLARY FROM VEHICLE        35        M
# 420025                 THEFT PLAIN - PETTY ($950 & UNDER)        65        F
# ...                                                   ...       ...      ...
# ...

# %%
tablestart = crime_timesummary['Hour'].unique()
tablestart
# Out:
# array(['0', '0000', '0100', '0200', '0300', '0400', '0500', '0600',
#        '0700', '0800', '0900', '1000', '1100', '1200', '1300', '1400',
#        '1500', '1600', '1700', '1800', '1900', '2000', ' 2100', '2200',
#        '2300'], dtype=object)

# %%
by_hour = crime_timesummary.groupby(['Hour'])
hour_summary = pd.DataFrame(by_hour[['Hour']].count())
hour_summary = hour_summary.rename(columns={'Hour':'Total per Hour'})
hour_summary
# Out:
#        Total per Hour
# Hour
#  2100           41216
# 0               14211
# 0000            19400
# 0100            24654
# 0200            20829
# 0300            18158
# 0400            15374
# 0500            14172
# 0600            18671
# 0700            20971
# 0800            29947
# 0900            29236
# 1000            34732
# 1100            35179
# 1200            55054
# 1300            36641
# 1400            39516
# 1500            42293
# 1600            42628
# 1700            47097
# 1800            48165
# 1900            44433
# 2000            45105
# 2200            39834
# 2300            34147

# %%
time_doubleohund = crime_timesummary.loc[crime_timesummary['Hour']=="0000"]
time_doubleohund
# Out:
#         TIME OCC    AREA NAME                                     Crm Cd Desc  \
# 497968         2    Southeast                               THEFT OF IDENTITY
# 572805         2     Foothill  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 767161         2       Newton                               THEFT OF IDENTITY
# 464686         2      Rampart                               THEFT OF IDENTITY
# 454841         2   Devonshire                               THEFT OF IDENTITY
# ...          ...          ...                                             ...
# 345539        59      West LA                                        BURGLARY
# 368702        59  West Valley                                        BURGLARY
# 519326        59  77th Street                                        BURGLARY
# 465233        59    Hollywood                           BURGLARY FROM VEHICLE
# 680475        59     Foothill                               THEFT OF IDENTITY
#
# ...

# %%
doubleo_summary = pd.DataFrame(time_doubleohund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
doubleo_summary
# Out:
#   AREA NAME        Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  THEFT OF IDENTITY         0        M            H  Invest Cont

# %%
time_onehund = crime_timesummary.loc[crime_timesummary['Hour']=="0100"]
time_onehund
# Out:
#         TIME OCC    AREA NAME  \
# 450892       100  West Valley
# 529344       100   Hollenbeck
# 802930       100       Newton
# 614137       100     Wilshire
# 673248       100      Central
# ...          ...          ...
# 544527       159      Olympic
# 703395       159    Hollywood
# 213114       159   Hollenbeck
# 659256       159    Hollywood
# 639422       159      Central
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 450892                                   VEHICLE - STOLEN         0      NaN
# 529344     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        23        F
# 802930                              BURGLARY FROM VEHICLE        55        F
# 614137                     DISCHARGE FIREARMS/SHOTS FIRED         0        M
# 673248                                        TRESPASSING        22        M
# ...                                                   ...       ...      ...
# ...

# %%
one_summary = pd.DataFrame(time_onehund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
one_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        M            H  Invest Cont

# %%
time_twohund = crime_timesummary.loc[crime_timesummary['Hour']=="0200"]
time_twohund
# Out:
#         TIME OCC    AREA NAME  \
# 681539       200  77th Street
# 511208       200       Harbor
# 405547       200     Wilshire
# 663022       200  N Hollywood
# 222142       200     Van Nuys
# ...          ...          ...
# 690338       259    Southeast
# 476908       259  West Valley
# 438658       259      Mission
# 290741       259  N Hollywood
# 336345       259      Pacific
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 681539                                   VEHICLE - STOLEN         0      NaN
# 511208                     VIOLATION OF RESTRAINING ORDER        42        F
# 405547                                   VEHICLE - STOLEN         0      NaN
# 663022                           BATTERY - SIMPLE ASSAULT        48        M
# 222142                  INTIMATE PARTNER - SIMPLE ASSAULT        27        F
# ...                                                   ...       ...      ...
# ...

# %%
two_summary = pd.DataFrame(time_twohund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
two_summary
# Out:
#   AREA NAME Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central    BURGLARY         0        M            H  Invest Cont

# %%
time_threehund = crime_timesummary.loc[crime_timesummary['Hour']=="0300"]
time_threehund
# Out:
#         TIME OCC    AREA NAME  \
# 404646       300    Hollywood
# 659109       300      Rampart
# 640538       300   Devonshire
# 165557       300    Southeast
# 327998       300      West LA
# ...          ...          ...
# 633624       359  N Hollywood
# 317529       359       Harbor
# 725162       359    Southwest
# 527458       359    Northeast
# 88724        359   Hollenbeck
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 404646                           BATTERY - SIMPLE ASSAULT        33        F
# 659109                                            ROBBERY        29        M
# 640538                                           BURGLARY        71        M
# 165557           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        60        M
# 327998                                   VEHICLE - STOLEN         0      NaN
# ...                                                   ...       ...      ...
# ...

# %%
thre_summary = pd.DataFrame(time_threehund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
thre_summary
# Out:
#      AREA NAME Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0  77th Street    BURGLARY         0        M            H  Invest Cont

# %%
time_fourhund = crime_timesummary.loc[crime_timesummary['Hour']=="0400"]
time_fourhund
# Out:
#         TIME OCC  AREA NAME  \
# 99740        400  Southeast
# 251          400    Central
# 710542       400    Mission
# 152153       400  Southeast
# 567852       400    Rampart
# ...          ...        ...
# 663447       459    Mission
# 86501        459     Harbor
# 527980       459    Central
# 506195       459     Harbor
# 181449       459     Newton
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 99740                   INTIMATE PARTNER - SIMPLE ASSAULT        48        F
# 251                 INTIMATE PARTNER - AGGRAVATED ASSAULT        38        M
# 710542                                           BURGLARY         0        M
# 152153                                        TRESPASSING        24        F
# 567852  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...         0        X
# ...                                                   ...       ...      ...
# 663447                                              ARSON        29        F
# ...

# %%
four_summary = pd.DataFrame(time_fourhund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
four_summary
# Out:
#   AREA NAME Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central    BURGLARY         0        M            H  Invest Cont

# %%
time_fivehund = crime_timesummary.loc[crime_timesummary['Hour']=="0500"]
time_fivehund
# Out:
#         TIME OCC    AREA NAME  \
# 466347       500      Rampart
# 711565       500      Central
# 361611       500     Foothill
# 193602       500  N Hollywood
# 198690       500    Southeast
# ...          ...          ...
# 630401       559    Northeast
# 457502       559    Northeast
# 342230       559    Hollywood
# 401136       559      Pacific
# 792759       559      Topanga
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 466347     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        41        M
# 711565                 THEFT PLAIN - PETTY ($950 & UNDER)        67        M
# 361611                     VIOLATION OF RESTRAINING ORDER        52        F
# 193602                 THEFT PLAIN - PETTY ($950 & UNDER)        37        F
# 198690                                            ROBBERY        19        M
# ...                                                   ...       ...      ...
# ...

# %%
five_summary = pd.DataFrame(time_fivehund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
five_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        M            H  Invest Cont

# %%
time_sixhund = crime_timesummary.loc[crime_timesummary['Hour']=="0600"]
time_sixhund
# Out:
#         TIME OCC    AREA NAME  \
# 273627       600       Newton
# 131164       600   Devonshire
# 271366       600       Harbor
# 251421       600  N Hollywood
# 279530       600  N Hollywood
# ...          ...          ...
# 293940       659   Devonshire
# 671262       659      Mission
# 593946       659  77th Street
# 472011       659    Southeast
# 539784       659  77th Street
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 273627                           BATTERY - SIMPLE ASSAULT         0        M
# 131164                  INTIMATE PARTNER - SIMPLE ASSAULT        47        F
# 271366  CRM AGNST CHLD (13 OR UNDER) (14-15 & SUSP 10 ...        15        F
# 251421                                   VEHICLE - STOLEN         0      NaN
# 279530                 THEFT PLAIN - PETTY ($950 & UNDER)        32        F
# ...                                                   ...       ...      ...
# ...

# %%
six_summary = pd.DataFrame(time_sixhund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
six_summary
# Out:
#      AREA NAME        Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0  77th Street  THEFT OF IDENTITY         0        F            H  Invest Cont

# %%
time_sevhund = crime_timesummary.loc[crime_timesummary['Hour']=="0700"]
time_sevhund
# Out:
#         TIME OCC    AREA NAME                                     Crm Cd Desc  \
# 149036       700     Foothill                                VEHICLE - STOLEN
# 198263       700  77th Street  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 652804       700      Central                        BATTERY - SIMPLE ASSAULT
# 807820       700    Southwest                               THEFT OF IDENTITY
# 679757       700       Harbor                               THEFT OF IDENTITY
# ...          ...          ...                                             ...
# 570267       759   Hollenbeck                               THEFT OF IDENTITY
# 276670       759      Pacific                               THEFT OF IDENTITY
# 614835       759     Van Nuys                                VEHICLE - STOLEN
# 408228       759    Hollywood                               THEFT OF IDENTITY
# 540143       759   Hollenbeck        VANDALISM - MISDEAMEANOR ($399 OR UNDER)
#
# ...

# %%
sev_summary = pd.DataFrame(time_sevhund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
sev_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        F            H  Invest Cont

# %%
time_eighthund = crime_timesummary.loc[crime_timesummary['Hour']=="0800"]
time_eighthund
# Out:
#         TIME OCC    AREA NAME  \
# 650844       800     Wilshire
# 432597       800    Southwest
# 558020       800    Southwest
# 537225       800      Topanga
# 343647       800    Northeast
# ...          ...          ...
# 583285       859     Wilshire
# 274339       859      Olympic
# 499740       859    Southwest
# 716050       859       Harbor
# 798729       859  N Hollywood
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 650844                                   VEHICLE - STOLEN         0      NaN
# 432597                  INTIMATE PARTNER - SIMPLE ASSAULT        21        F
# 558020  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        34        M
# 537225     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        23        M
# 343647                                   VEHICLE - STOLEN         0      NaN
# ...                                                   ...       ...      ...
# ...

# %%
ate_summary = pd.DataFrame(time_eighthund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
ate_summary
# Out:
#      AREA NAME        Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0  77th Street  THEFT OF IDENTITY         0        F            H  Invest Cont

# %%
time_ninehund = crime_timesummary.loc[crime_timesummary['Hour']=="0900"]
time_ninehund
# Out:
#         TIME OCC    AREA NAME                               Crm Cd Desc  \
# 382951       900  77th Street                          VEHICLE - STOLEN
# 389207       900   Devonshire    CRIMINAL THREATS - NO WEAPON DISPLAYED
# 594900       900     Wilshire                          VEHICLE - STOLEN
# 412999       900      Topanga     INTIMATE PARTNER - AGGRAVATED ASSAULT
# 741995       900       Newton                          VEHICLE - STOLEN
# ...          ...          ...                                       ...
# 122033       959   Devonshire                        BUNCO, GRAND THEFT
# 754349       959    Hollywood  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)
# 540670       959      Mission        THEFT PLAIN - PETTY ($950 & UNDER)
# 784116       959     Wilshire  SHOPLIFTING - PETTY THEFT ($950 & UNDER)
# 19049        959       Harbor                        BUNCO, PETTY THEFT
#
#         Vict Age Vict Sex Vict Descent  Status Desc      LAT       LON  Hour
# ...

# %%
nine_summary = pd.DataFrame(time_ninehund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
nine_summary
# Out:
#   AREA NAME        Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  THEFT OF IDENTITY         0        M            H  Invest Cont

# %%
time_tenhund = crime_timesummary.loc[crime_timesummary['Hour']=="1000"]
time_tenhund
# Out:
#         TIME OCC    AREA NAME                                     Crm Cd Desc  \
# 412264      1000      Central              THEFT PLAIN - PETTY ($950 & UNDER)
# 249504      1000     Wilshire                           BURGLARY FROM VEHICLE
# 412570      1000   Devonshire                       OTHER MISCELLANEOUS CRIME
# 66600       1000      West LA  ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT
# 66974       1000  West Valley               INTIMATE PARTNER - SIMPLE ASSAULT
# ...          ...          ...                                             ...
# 535151      1059  77th Street        VANDALISM - MISDEAMEANOR ($399 OR UNDER)
# 438538      1059     Van Nuys                               THEFT OF IDENTITY
# 263439      1059      Pacific              THEFT PLAIN - PETTY ($950 & UNDER)
# 200370      1059     Foothill                               THEFT OF IDENTITY
# 717108      1059      Rampart        SHOPLIFTING - PETTY THEFT ($950 & UNDER)
#
# ...

# %%
ten_summary = pd.DataFrame(time_tenhund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
ten_summary
# Out:
#   AREA NAME               Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 0   Central  BATTERY - SIMPLE ASSAULT         0        M            H
#
#    Status Desc
# 0  Invest Cont

# %%
time_elevhund = crime_timesummary.loc[crime_timesummary['Hour']=="1100"]
time_elevhund
# Out:
#         TIME OCC    AREA NAME  \
# 199264      1100     Van Nuys
# 661445      1100  West Valley
# 103293      1100    Southeast
# 360848      1100     Van Nuys
# 629474      1100   Hollenbeck
# ...          ...          ...
# 138193      1159      Olympic
# 548942      1159  West Valley
# 523768      1159    Southwest
# 551016      1159      West LA
# 148800      1159      Pacific
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 199264                                  THEFT OF IDENTITY        70        F
# 661445                              BURGLARY FROM VEHICLE        44        M
# 103293                           BATTERY - SIMPLE ASSAULT        32        F
# 360848  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        45        M
# 629474  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        33        M
# ...                                                   ...       ...      ...
# ...

# %%
elev_summary = pd.DataFrame(time_elevhund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
elev_summary
# Out:
#   AREA NAME               Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 0   Central  BATTERY - SIMPLE ASSAULT         0        M            H
#
#    Status Desc
# 0  Invest Cont

# %%
time_twelvhund = crime_timesummary.loc[crime_timesummary['Hour']=="1200"]
time_twelvhund
# Out:
#         TIME OCC    AREA NAME  \
# 326307      1200    Southeast
# 781064      1200       Harbor
# 411626      1200      Olympic
# 710743      1200       Harbor
# 131921      1200      Topanga
# ...          ...          ...
# 805976      1259      Central
# 184022      1259  N Hollywood
# 560388      1259     Wilshire
# 699828      1259   Hollenbeck
# 516451      1259     Foothill
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 326307                                   VEHICLE - STOLEN         0      NaN
# 781064  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...        29        M
# 411626                                           BURGLARY        73        F
# 710743  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        34        F
# 131921    THEFT FROM MOTOR VEHICLE - PETTY ($950 & UNDER)         0      NaN
# ...                                                   ...       ...      ...
# ...

# %%
twelv_summary = pd.DataFrame(time_twelvhund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
twelv_summary
# Out:
#   AREA NAME        Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Pacific  THEFT OF IDENTITY         0        F            H  Invest Cont

# %%
time_thirthund = crime_timesummary.loc[crime_timesummary['Hour']=="1300"]
time_thirthund
# Out:
#         TIME OCC    AREA NAME  \
# 406197      1300       Harbor
# 454606      1300   Hollenbeck
# 93580       1300    Hollywood
# 478311      1300       Harbor
# 419302      1300       Harbor
# ...          ...          ...
# 635075      1359      West LA
# 222432      1359  N Hollywood
# 636383      1359      Topanga
# 507440      1359  77th Street
# 279398      1359    Southwest
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 406197                                    BRANDISH WEAPON        40        M
# 454606                                   VEHICLE - STOLEN         0      NaN
# 93580                                   THEFT OF IDENTITY        28        F
# 478311                                           BURGLARY         0        X
# 419302            CHILD ABUSE (PHYSICAL) - SIMPLE ASSAULT        17        F
# ...                                                   ...       ...      ...
# ...

# %%
thirt_summary = pd.DataFrame(time_thirthund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
thirt_summary
# Out:
#   AREA NAME               Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 0   Central  BATTERY - SIMPLE ASSAULT         0        M            H
#
#    Status Desc
# 0  Invest Cont

# %%
time_fourthund = crime_timesummary.loc[crime_timesummary['Hour']=="1400"]
time_fourthund
# Out:
#         TIME OCC   AREA NAME  \
# 442809      1400  Devonshire
# 312736      1400   Hollywood
# 660357      1400     Pacific
# 458108      1400    Foothill
# 134980      1400      Newton
# ...          ...         ...
# 315382      1459    Van Nuys
# 719544      1459     West LA
# 233861      1459     West LA
# 704255      1459      Newton
# 74427       1459   Northeast
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 442809                                  THEFT OF IDENTITY        61        M
# 312736                                    BRANDISH WEAPON        57        M
# 660357                                   VEHICLE - STOLEN         0      NaN
# 458108                                   VEHICLE - STOLEN         0      NaN
# 134980                           BATTERY - SIMPLE ASSAULT        38        M
# ...                                                   ...       ...      ...
# ...

# %%
fourt_summary = pd.DataFrame(time_fourthund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
fourt_summary
# Out:
#   AREA NAME               Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 0   Central  BATTERY - SIMPLE ASSAULT         0        M            H
#
#    Status Desc
# 0  Invest Cont

# %%
time_fifthund = crime_timesummary.loc[crime_timesummary['Hour']=="1500"]
time_fifthund
# Out:
#         TIME OCC    AREA NAME  \
# 495168      1500      Rampart
# 438320      1500    Northeast
# 557840      1500   Devonshire
# 604389      1500    Hollywood
# 608612      1500    Northeast
# ...          ...          ...
# 483666      1559     Foothill
# 604483      1559      West LA
# 349145      1559  N Hollywood
# 200236      1559  N Hollywood
# 132007      1559     Wilshire
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 495168  VEHICLE, STOLEN - OTHER (MOTORIZED SCOOTERS, B...         0      NaN
# 438320           SHOPLIFTING - PETTY THEFT ($950 & UNDER)         0        M
# 557840                           BATTERY - SIMPLE ASSAULT        69        M
# 604389                                     BUNCO, ATTEMPT        60        M
# 608612                 THEFT PLAIN - PETTY ($950 & UNDER)        22        M
# ...                                                   ...       ...      ...
# ...

# %%
fift_summary = pd.DataFrame(time_fifthund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
fift_summary
# Out:
#   AREA NAME               Crm Cd Desc  Vict Age Vict Sex Vict Descent  \
# 0   Central  BATTERY - SIMPLE ASSAULT         0        M            H
#
#    Status Desc
# 0  Invest Cont

# %%
time_sixthund = crime_timesummary.loc[crime_timesummary['Hour']=="1600"]
time_sixthund
# Out:
#         TIME OCC    AREA NAME  \
# 696005      1600    Southwest
# 502898      1600   Devonshire
# 805953      1600   Devonshire
# 178216      1600      Mission
# 565788      1600      Rampart
# ...          ...          ...
# 44743       1659  West Valley
# 527492      1659      Central
# 383332      1659      Mission
# 293089      1659  West Valley
# 610673      1659      Pacific
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 696005     ASSAULT WITH DEADLY WEAPON, AGGRAVATED ASSAULT        52        M
# 502898  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...         0        X
# 805953                                   VEHICLE - STOLEN         0      NaN
# 178216                                   VEHICLE - STOLEN         0      NaN
# 565788                                   VEHICLE - STOLEN         0      NaN
# ...                                                   ...       ...      ...
# ...

# %%
sixt_summary = pd.DataFrame(time_sixthund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
sixt_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        M            H  Invest Cont

# %%
time_decsepthund = crime_timesummary.loc[crime_timesummary['Hour']=="1700"]
time_decsepthund
# Out:
#         TIME OCC    AREA NAME  \
# 60995       1700      Rampart
# 323126      1700     Foothill
# 558216      1700  77th Street
# 352727      1700      West LA
# 319377      1700  N Hollywood
# ...          ...          ...
# 748399      1759   Hollenbeck
# 268192      1759  West Valley
# 777799      1759    Northeast
# 687994      1759      Mission
# 308817      1759      Pacific
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 60995                                            BURGLARY        35        F
# 323126  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        65        M
# 558216                                   VEHICLE - STOLEN         0      NaN
# 352727                                  THEFT OF IDENTITY        44        M
# 319377  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        38        F
# ...                                                   ...       ...      ...
# ...

# %%
dsept_summary = pd.DataFrame(time_decsepthund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
dsept_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        M            H  Invest Cont

# %%
time_octhund = crime_timesummary.loc[crime_timesummary['Hour']=="1800"]
time_octhund
# Out:
#         TIME OCC    AREA NAME  \
# 529958      1800      Central
# 143726      1800      Pacific
# 781267      1800    Southeast
# 216394      1800     Wilshire
# 449106      1800  77th Street
# ...          ...          ...
# 197174      1859      Pacific
# 486244      1859       Newton
# 670806      1859     Wilshire
# 421939      1859    Southwest
# 394598      1859   Devonshire
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 529958                                         PICKPOCKET        58        F
# 143726              INTIMATE PARTNER - AGGRAVATED ASSAULT        27        F
# 781267                  INTIMATE PARTNER - SIMPLE ASSAULT        27        F
# 216394  THEFT-GRAND ($950.01 & OVER)EXCPT,GUNS,FOWL,LI...        50        M
# 449106                           BATTERY - SIMPLE ASSAULT        47        F
# ...                                                   ...       ...      ...
# ...

# %%
oct_summary = pd.DataFrame(time_octhund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
oct_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        M            H  Invest Cont

# %%
time_neufhund = crime_timesummary.loc[crime_timesummary['Hour']=="1900"]
time_neufhund
# Out:
#         TIME OCC    AREA NAME  \
# 364804      1900    Hollywood
# 653685      1900    Northeast
# 737777      1900      West LA
# 224669      1900     Van Nuys
# 62198       1900    Northeast
# ...          ...          ...
# 735679      1959  77th Street
# 664724      1959     Wilshire
# 273315      1959      Olympic
# 643870      1959      West LA
# 549280      1959      Central
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 364804                              BURGLARY FROM VEHICLE        35        F
# 653685                           VEHICLE - ATTEMPT STOLEN        22        F
# 737777  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        49        M
# 224669                                   VEHICLE - STOLEN         0      NaN
# 62198              CRIMINAL THREATS - NO WEAPON DISPLAYED        27        F
# ...                                                   ...       ...      ...
# ...

# %%
neuf_summary = pd.DataFrame(time_neufhund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
neuf_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        M            H  Invest Cont

# %%
time_vnthund = crime_timesummary.loc[crime_timesummary['Hour']=="2000"]
time_vnthund
# Out:
#         TIME OCC    AREA NAME  \
# 375583      2000   Hollenbeck
# 303793      2000    Northeast
# 162231      2000    Northeast
# 162258      2000       Newton
# 288847      2000  N Hollywood
# ...          ...          ...
# 748432      2059  77th Street
# 355077      2059       Newton
# 96560       2059    Southwest
# 211071      2059   Hollenbeck
# 616906      2059  N Hollywood
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 375583                                   VEHICLE - STOLEN         0      NaN
# 303793                              BURGLARY FROM VEHICLE        37        F
# 162231  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        53        M
# 162258                              BURGLARY FROM VEHICLE        64        F
# 288847           VANDALISM - MISDEAMEANOR ($399 OR UNDER)        32        M
# ...                                                   ...       ...      ...
# ...

# %%
vnt_summary = pd.DataFrame(time_vnthund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
vnt_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        M            H  Invest Cont

# %%
time_vntunhund = crime_timesummary.loc[crime_timesummary['Hour']=="2100"]
time_vntunhund
# Out:
# Empty DataFrame
# Columns: [TIME OCC, AREA NAME, Crm Cd Desc, Vict Age, Vict Sex, Vict Descent, Status Desc, LAT, LON, Hour]
# Index: []

# %%
vntun_summary = pd.DataFrame(time_vntunhund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
vntun_summary
# Out:
# Empty DataFrame
# Columns: [AREA NAME, Crm Cd Desc, Vict Age, Vict Sex, Vict Descent, Status Desc]
# Index: []

# %%
time_twotwohund = crime_timesummary.loc[crime_timesummary['Hour']=="2200"]
time_twotwohund
# Out:
#         TIME OCC    AREA NAME  \
# 309929      2200    Northeast
# 43385       2200   Hollenbeck
# 764172      2200      Central
# 775189      2200    Southwest
# 36165       2200   Hollenbeck
# ...          ...          ...
# 68654       2259     Wilshire
# 711850      2259     Wilshire
# 561960      2259  77th Street
# 689070      2259    Southeast
# 25196       2259   Hollenbeck
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 309929  VANDALISM - FELONY ($400 & OVER, ALL CHURCH VA...        57        M
# 43385                            BATTERY - SIMPLE ASSAULT        21        F
# 764172  THEFT FROM MOTOR VEHICLE - GRAND ($950.01 AND ...        29        M
# 775189                                      BIKE - STOLEN        35        F
# 36165                      CHILD ANNOYING (17YRS & UNDER)        14        F
# ...                                                   ...       ...      ...
# ...

# %%
twotwo_summary = pd.DataFrame(time_twotwohund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
twotwo_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        M            H  Invest Cont

# %%
time_twothreehund = crime_timesummary.loc[crime_timesummary['Hour']=="2300"]
time_twothreehund
# Out:
#         TIME OCC    AREA NAME  \
# 785193      2300  77th Street
# 548275      2300      Pacific
# 639852      2300    Southeast
# 117148      2300       Newton
# 339108      2300      Olympic
# ...          ...          ...
# 660968      2359      Topanga
# 770037      2359  N Hollywood
# 477570      2359     Wilshire
# 740638      2359    Hollywood
# 378634      2359     Van Nuys
#
#                                               Crm Cd Desc  Vict Age Vict Sex  \
# 785193                  INTIMATE PARTNER - SIMPLE ASSAULT        40        F
# 548275                                   VEHICLE - STOLEN         0      NaN
# 639852                  INTIMATE PARTNER - SIMPLE ASSAULT        25        M
# 117148                           BATTERY - SIMPLE ASSAULT        52        M
# 339108                                           BURGLARY        42        F
# ...                                                   ...       ...      ...
# ...

# %%
twothree_summary = pd.DataFrame(time_twothreehund[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
                                              "Status Desc"]].mode())
twothree_summary
# Out:
#   AREA NAME       Crm Cd Desc  Vict Age Vict Sex Vict Descent  Status Desc
# 0   Central  VEHICLE - STOLEN         0        M            H  Invest Cont

# %%
# data = {'col_1': [3, 2, 1, 0], 'col_2': ['a', 'b', 'c', 'd']}
# pd.DataFrame.from_dict(data)
#data for 2100 did not populate, see output "vntun_summary" above.
done = {
        'Hour' : ['0000', '0100', '0200', '0300', '0400', '0500', '0600', '0700', '0800', '0900', '1000', '1100', 
                '1200', '1300', '1400', '1500', '1600', '1700', '1800', '1900', '2000', '2100', '2200', '2300'],
        'Crimes per Hour' : [19400, 24654, 20829, 18158, 15374, 14172, 18671, 20971, 29947, 29236, 34732, 35179,
                            55054, 36641, 39516, 42293, 42628, 47097, 48165, 44433, 45105, 41216, 39834, 34147],
        'Area Name' : ['Central', 'Central', 'Central', '77th Street', 'Central', 'Central', '77th Street', 'Central',
                       '77th Street', 'Central', 'Central', 'Central', 'Pacific', 'Central', 'Central', 'Central',
                       'Central', 'Central', 'Central', 'Central', 'Central', 'NULL', 'Central', 'Central'],
        'Crm Cd Desc' : ['THEFT OF IDENTITY', 'VEHICLE – STOLEN', 'BURGLARY', 'BURGLARY', 'BURGLARY', 'VEHICLE – STOLEN', 
                         'THEFT OF IDENTITY', 'VEHICLE – STOLEN', 'THEFT OF IDENTITY', 'THEFT OF IDENTITY', 
                         'BATTERY – SIMPLE ASSAULT', 'BATTERY – SIMPLE ASSAULT', 'THEFT OF IDENTITY', 'BATTERY – SIMPLE ASSAULT',
                         'BATTERY – SIMPLE ASSAULT', 'BATTERY – SIMPLE ASSAULT', 'VEHICLE – STOLEN', 'VEHICLE – STOLEN',
                         'VEHICLE – STOLEN', 'VEHICLE – STOLEN', 'VEHICLE – STOLEN', 'NULL', 'VEHICLE – STOLEN',
                         'VEHICLE – STOLEN'],
        'Vict Sex' : ['M', 'M', 'M', 'M', 'M', 'M', 'F', 'F', 'F', 'M', 'M', 'M', 'F', 'M', 'M', 'M', 'M', 'M', 'M',
                      'M', 'M', 'NULL', 'M', 'M'],
        'Status Desc' : ['H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H', 'H',
                         'H', 'H', 'NULL', 'H', 'H']
}

summary_time = pd.DataFrame(data=done)
summary_time
# Out:
#     Hour  Crimes per Hour    Area Name               Crm Cd Desc Vict Sex  \
# 0   0000            19400      Central         THEFT OF IDENTITY        M
# 1   0100            24654      Central          VEHICLE – STOLEN        M
# 2   0200            20829      Central                  BURGLARY        M
# 3   0300            18158  77th Street                  BURGLARY        M
# 4   0400            15374      Central                  BURGLARY        M
# 5   0500            14172      Central          VEHICLE – STOLEN        M
# 6   0600            18671  77th Street         THEFT OF IDENTITY        F
# 7   0700            20971      Central          VEHICLE – STOLEN        F
# 8   0800            29947  77th Street         THEFT OF IDENTITY        F
# 9   0900            29236      Central         THEFT OF IDENTITY        M
# 10  1000            34732      Central  BATTERY – SIMPLE ASSAULT        M
# 11  1100            35179      Central  BATTERY – SIMPLE ASSAULT        M
# ...

# %%
labels = ['THEFT OF IDENTITY', 'VEHICLE – STOLEN', 'BURGLARY', 'BATTERY – SIMPLE ASSAULT' ]
sizes = [5, 10, 3, 5]
colors = ['pink', 'red', 'lightblue', 'lightcoral']
explode = (0, 0, 0, 0)

# %%
plt.pie(sizes, explode=explode, labels=labels, autopct="%0.2f%%", colors=colors, startangle =90)
plt.axis("equal")
plt.savefig("Images/hourly_crime_pie.png")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#UNUSED codes and failed attempts
# bins = [0,59,159,259,359,459,559,659,759,859,959,1059,1159,1259,1359,1459,1559,1659,1759,1859,1959,2059,2159,2259,2359]
# hour = ["0000", "0100", "0200", "0300", "0400", "0500", "0600", "0700", "0800", "0900", "1000", "1100", "1200", 
#         "1300", "1400", "1500", "1600", "1700", "1800", "1900", "2000", "2100", "2200", "2300"]

# Slice the data and place it into bins
# movies_df["IMDB User Votes Group"] = pd.cut(movies_df["IMDB_user_vote_count"], bins, labels=group_labels)

# crime_timesort["Hours"] = pd.cut(time_crime["TIME OCC"], bins, labels=hour)

# Create a GroupBy object based upon "IMDB User Votes Group"
# imdb_group = movies_df.groupby("IMDB User Votes Group")
# crime_timesort = crime_timesort.groupby("Hours")

# Find how many rows fall into each bin
# print(imdb_group["IMDB"].count())
# by_regimen = clean_mice.groupby(["Drug Regimen"])
# regimen_stats = pd.DataFrame(by_regimen[["Tumor Volume (mm3)"]].mean())
# regimen_stats = regimen_stats.rename(columns={"Tumor Volume (mm3)": "Mean Tumor Volume"})
# regimen_stats
# time_crimestats = pd.DataFrame(time_crime[["TIME OCC"]].count())
# time_crimestats = pd.DataFrame(crime_timesort[["AREA NAME", "Crm Cd Desc", "Vict Age", "Vict Sex", "Vict Descent", 
#                                               "Status Desc"]].mode())
# df['name'].mode()
# Get the average of each of the first 5 rating columns within the GroupBy object
# imdb_group[["RottenTomatoes", "RottenTomatoes_User", "Metacritic", "Metacritic_User", "IMDB"]].mean()

# %%
# time_summary = time_crime.groupby(["TIME OCC"])
# time_crime_summary = pd.DataFrame

# %%
# pd.concat(objs,axis=0,join="outer",ignore_index=False,keys=None,levels=None,names=None,verify_integrity=False,copy=True,)

# %%
# df['Category'] = pd.cut(df["Age"],bins,labels = category)
# df['Times'] = pd.cut(time_crime["TIME OCC"],bins, labels = category)

# %%
# by_regimen = clean_mice.groupby(["Drug Regimen"])
# regimen_stats = pd.DataFrame(by_regimen[["Tumor Volume (mm3)"]].mean())
# regimen_stats = regimen_stats.rename(columns={"Tumor Volume (mm3)": "Mean Tumor Volume"})
# regimen_stats
# new = old[['A','C','D']]
# new = old.filter(['A','B','D'], axis=1)
# time_two = lapd_two.groupby(["TIME OCC"])
# time_crimetwo = pd.DataFrame([time_two.AREA NAME, time_two.Crm Cd Desc, time_two.Vict Age, time_two.Vict Sex, 
#                           time_two.Vict Descent,time_two.Status Desc, time_two.LAT, time_two.LON]).transpose()
# time_three = lapd_three.groupby(["TIME OCC"])
# time_crimethree = pd.DataFrame([time_three.AREA NAME, time_three.Crm Cd Desc, time_three.Vict Age, time_three.Vict Sex, 
#                           time_three.Vict Descent,time_three.Status Desc, time_three.LAT, time_three.LON]).transpose()
# time_four = lapd_four.groupby(["TIME OCC"])
# time_crimefour = pd.DataFrame([time_four.AREA NAME, time_four.Crm Cd Desc, time_four.Vict Age, time_four.Vict Sex, 
#                           time_four.Vict Descent,time_four.Status Desc, time_four.LAT, time_four.LON]).transpose()
# time_five = lapd_five.groupby(["TIME OCC"])
# time_crimefive = pd.DataFrame([time_five.AREA NAME, time_five.Crm Cd Desc, time_five.Vict Age, time_five.Vict Sex, 
#                           time_five.Vict Descent,time_fiveo.Status Desc, time_five.LAT, time_five.LON]).transpose()
# time_six = lapd_six.groupby(["TIME OCC"])
# time_crimesix = pd.DataFrame([time_six.AREA NAME, time_six.Crm Cd Desc, time_six.Vict Age, time_six.Vict Sex, 
#                           time_six.Vict Descent,time_six.Status Desc, time_six.LAT, time_six.LON]).transpose()
# time_seven = lapd_seven.groupby(["TIME OCC"])
# time_crimeseven = pd.DataFrame([time_seven.AREA NAME, time_seven.Crm Cd Desc, time_seven.Vict Age, time_seven.Vict Sex, 
#                           time_seven.Vict Descent,time_seven.Status Desc, time_seven.LAT, time_seven.LON]).transpose()
# time_eight = lapd_eight.groupby(["TIME OCC"])
# time_crimeeight = pd.DataFrame([time_eight.AREA NAME, time_eight.Crm Cd Desc, time_eight.Vict Age, time_eight.Vict Sex, 
#                           time_eight.Vict Descent,time_eight.Status Desc, time_eight.LAT, time_two.LON]).transpose()
# time_nine = lapd_nine.groupby(["TIME OCC"])
# time_crimenine = pd.DataFrame([time_nine.AREA NAME, time_nine.Crm Cd Desc, time_nine.Vict Age, time_nine.Vict Sex, 
#                           time_nine.Vict Descent,time_nine.Status Desc, time_nine.LAT, time_nine.LON]).transpose()
# time_ten = lapd_ten.groupby(["TIME OCC"])
# time_crimeten = pd.DataFrame([time_ten.AREA NAME, time_ten.Crm Cd Desc, time_ten.Vict Age, time_ten.Vict Sex, 
#                           time_ten.Vict Descent,time_ten.Status Desc, time_ten.LAT, time_ten.LON]).transpose()
# crimesummary_one = time_crime.merge(time_crimetwo, on=["TIME OCC"]).join(time_crimethree,on="TIME OCC")
# crimesummary_two = time_crimefour.merge(time_crimefive, on=["TIME OCC"]).join(time_crimesix,on="TIME OCC")
# crimesummary_three = time_crimeseven.merge(time_crimeeight, on=["TIME OCC"]).join(time_crimenine,on="TIME OCC")
# crimesummary_four = crimesummary_one.merge(crimesummary_two, on=["TIME OCC"]).join_compat(crimesummary_three,on="TIME OCC")
# bins = [0,59,159,259,359,459,559,659,759,859,959,1059,1159,1259,1359,1459,1559,1659,1759,1859,1959,2059,2159,2259,2359]
# category = [0, 100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200, 1300, 1400, 1500, 1600, 1700, 1800, 1900,
#            2000, 2100, 2200, 2300]
